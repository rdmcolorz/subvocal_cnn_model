# %%
import matplotlib.pyplot as plt
from matplotlib.backend_bases import RendererBase
from scipy import signal
from scipy.io import wavfile
#import soundfile as sf
import os
import glob
import numpy as np
from PIL import Image, ImageEnhance
from scipy.fftpack import fft
from scipy.misc import imresize
from IPython.core.display import HTML
import numpy as np
import pandas as pd
from sklearn import metrics
import tensorflow as tf
import operator
import seaborn as sns
import cv2
import random
import tensorflow_hub as hub
import librosa
from tensorflow.python.data import Dataset
import librosa.display
# %matplotlib inline
tf.logging.set_verbosity(tf.logging.ERROR)

# %%
audio_path = './data/no_vocal/'
pic_path = "./data/no_vocal2/"
data_labels = os.listdir(audio_path)
data_labels.pop(2)
data_labels
# Out:
# ['no', 'stop']

# %%
def log_specgram(audio, sample_rate, window_size=20,
                 step_size=10, eps=1e-10):
    nperseg = int(round(window_size * sample_rate / 1e3))
    noverlap = int(round(step_size * sample_rate / 1e3))
    freqs, _, spec = signal.spectrogram(audio,
                                    fs=sample_rate,
                                    window='hann',
                                    nperseg=nperseg,
                                    noverlap=noverlap,
                                    detrend=False,
                                    nfft=1024)
    return freqs, np.log(spec.T.astype(np.float32) + eps)

# %%
def wav2img(wav_path, targetdir='', figsize=(4,4)):
    samplerate, test_sound  = wavfile.read(wav_path)
    spectrogram = librosa.feature.melspectrogram(test_sound, sr=samplerate, n_mels=128, fmax=512)

    
    output_file = wav_path.split('/')[-1].split('.wav')[0]
    output_file = targetdir +'/'+ output_file
    #plt.imshow(spectrogram.T, aspect='auto', origin='lower')
    spectrogram = librosa.feature.melspectrogram(test_sound, sr=samplerate, n_mels=128, fmax=512)

    # Convert to log scale (dB). We'll use the peak power (max) as reference.
    spectrogram = librosa.power_to_db(spectrogram, ref=np.max)
    spectrogram = imresize(spectrogram, (96,96))
    plt.figure(figsize=(12, 4))
    librosa.display.specshow(spectrogram, sr=samplerate, x_axis='time', y_axis='mel')
    plt.tight_layout()
    plt.imsave('%s.jpg' % output_file, spectrogram)
    plt.close()
    return spectrogram

# %%
# sample = []
# for label in labels:
#     for channel in range(1,4):
#         ch_sample = os.listdir(audio_path + label + "/" + "ch" + str(channel))[:1]
#         for x in ch_sample:
#             sample.append(audio_path + label + "/" + "ch" + str(channel) + "/" + x)

# sample
# len(sample)

# %%
# sample_audio = sample
# for i, filepath in enumerate(sample_audio[:3]):
#     # Make subplots
#     plt.subplot(1,3,i+1)
#     # pull the labels
#     plt.title(i)

#     # create spectogram
#     samplerate, test_sound  = wavfile.read(filepath)
#     _, spectrogram = log_specgram(test_sound, samplerate)

#     plt.imshow(spectrogram.T, aspect="auto", origin='lower')
#     plt.axis('off')

# %%
# for i, filepath in enumerate(sample_audio[3:6]):
#     # Make subplots
#     plt.subplot(1,3,i+1)
#     # pull the labels
#     plt.title(i)

#     # create spectogram
#     samplerate, test_sound  = wavfile.read(filepath)
#     _, spectrogram = log_specgram(test_sound, samplerate)

#     plt.imshow(spectrogram.T, aspect="auto", origin='lower')
#     plt.axis('off')

# %%
# for i, filepath in enumerate(sample_audio[6:9]):
#     # Make subplots
#     plt.subplot(1,3,i+1)
#     # pull the labels
#     plt.title(i)

#     # create spectogram
#     samplerate, test_sound  = wavfile.read(filepath)
#     _, spectrogram = log_specgram(test_sound, samplerate)

#     plt.imshow(spectrogram.T, aspect="auto", origin='lower')
#     plt.axis('off')

# %%
labels_to_keep = ['yes', 'no', 'up', 'down', 'left',
                  'right', 'on', 'off', 'stop', 'go']

test_labels = ['yes', 'no', 'up', 'down', 'left',
                  'right', 'on', 'off', 'stop', 'go', 'silence']

label_dict = {'yes':0, 'no':1,'stop':2}

reverse_dict = {v: k for k, v in label_dict.items()}

# %%
# for i, x in enumerate(labels):
#         all_files = [y for y in os.listdir(audio_path + x) if '.wav' in y]
#         for file in all_files[:]:
#             wav2img(audio_path + x + '/' + file, './data/img/' + x)

# %%
# make the pict data directory with label folders

data = "./data/"
labels = ['no','stop','yes']
for f in labels:
    if not os.path.exists("./data/no_vocal2" + f): 
        os.mkdir("./data/no_vocal2/" + f)
    for i in range(1,9):
        if not os.path.exists("./data/no_voal2/" + f + "/" + "ch" + str(i)):
            os.mkdir("./data/no_vocal2/" + f + "/" + "ch" + str(i))

# %%
#code for turning wav files into jpg.
for i, x in enumerate(['no', 'stop']):
    print(i, ':', x)
    # get all the wave files
    for i in range(1,2):
        all_files = [y for y in os.listdir(audio_path + x + "/" + "ch" + str(i)) if '.wav' in y]
        for file in all_files:
            if not any(x in file for x in ['204', '205', '197']):
                wav2img(audio_path + x + "/" + "ch" + str(i) + '/' + file, pic_path + x + "/" + "ch" + str(i))
                print("%s %s %s" %(x, str(i), file))
# Out:
# 0 : no
# /home/rainbowww5/anaconda3/lib/python3.5/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
# no 1 00156_jul23.wav
# no 1 00340_jul24.wav
# no 1 00427_jul24.wav
# no 1 00555_jul20.wav
# no 1 00146_jul24.wav
# no 1 00308_jul23.wav
# no 1 00169_jul23.wav
# no 1 00020_jul23.wav
# no 1 00093_jul09.wav
# no 1 00167_jul09.wav
# no 1 00277_jul24.wav
# no 1 00613_jul24.wav
# no 1 00045_jul23.wav
# no 1 00102_jul24.wav
# no 1 00566_jul20.wav
# no 1 00202_jul20.wav
# no 1 00238_jul23.wav
# no 1 00227_jul24.wav
# no 1 00097_jul20.wav
# no 1 00480_jul23.wav
# no 1 00393_jul23.wav
# no 1 00527_jul20.wav
# no 1 00302_jul20.wav
# no 1 00140_jul23.wav
# no 1 00468_jul20.wav
# no 1 00200_jul09.wav
# no 1 00223_jul23.wav
# no 1 00039_jul24.wav
# no 1 00076_jul09.wav
# no 1 00107_jul20.wav
# no 1 00503_jul23.wav
# no 1 00208_jul24.wav
# no 1 00038_jul20.wav
# no 1 00490_jul20.wav
# no 1 00040_jul09.wav
# no 1 00456_jul23.wav
# no 1 00156_jul20.wav
# no 1 00387_jul23.wav
# no 1 00082_jul20.wav
# no 1 00540_jul20.wav
# no 1 00153_jul23.wav
# no 1 00381_jul23.wav
# no 1 00337_jul20.wav
# no 1 00082_jul09.wav
# no 1 00364_jul24.wav
# no 1 00167_jul20.wav
# no 1 00342_jul20.wav
# no 1 00271_jul23.wav
# no 1 00393_jul20.wav
# no 1 00575_jul20.wav
# no 1 00117_jul23.wav
# no 1 00041_jul23.wav
# no 1 00358_jul24.wav
# no 1 00401_jul24.wav
# no 1 00129_jul23.wav
# no 1 00028_jul09.wav
# no 1 00316_jul20.wav
# no 1 00093_jul23.wav
# no 1 00250_jul23.wav
# no 1 00284_jul20.wav
# no 1 00193_jul09.wav
# no 1 00086_jul09.wav
# no 1 00433_jul20.wav
# no 1 00016_jul24.wav
# no 1 00404_jul23.wav
# no 1 00451_jul24.wav
# no 1 00458_jul24.wav
# no 1 00474_jul23.wav
# no 1 00096_jul24.wav
# no 1 00109_jul20.wav
# no 1 00075_jul09.wav
# no 1 00098_jul20.wav
# no 1 00189_jul20.wav
# no 1 00598_jul24.wav
# no 1 00031_jul24.wav
# no 1 00227_jul20.wav
# no 1 00127_jul24.wav
# no 1 00490_jul23.wav
# no 1 00174_jul24.wav
# no 1 00298_jul23.wav
# no 1 00429_jul20.wav
# no 1 00528_jul24.wav
# no 1 00416_jul23.wav
# no 1 00010_jul09.wav
# no 1 00276_jul23.wav
# no 1 00529_jul24.wav
# no 1 00040_jul20.wav
# no 1 00512_jul24.wav
# no 1 00101_jul23.wav
# no 1 00502_jul20.wav
# no 1 00162_jul24.wav
# no 1 00147_jul20.wav
# no 1 00568_jul24.wav
# no 1 00442_jul24.wav
# no 1 00351_jul23.wav
# no 1 00509_jul23.wav
# no 1 00408_jul24.wav
# no 1 00495_jul24.wav
# no 1 00445_jul24.wav
# no 1 00431_jul23.wav
# no 1 00273_jul23.wav
# no 1 00107_jul09.wav
# no 1 00088_jul09.wav
# no 1 00327_jul20.wav
# no 1 00444_jul23.wav
# no 1 00427_jul23.wav
# no 1 00055_jul20.wav
# no 1 00265_jul23.wav
# no 1 00520_jul24.wav
# no 1 00025_jul09.wav
# no 1 00507_jul20.wav
# no 1 00094_jul24.wav
# no 1 00093_jul24.wav
# no 1 00029_jul09.wav
# no 1 00005_jul24.wav
# no 1 00190_jul09.wav
# no 1 00460_jul20.wav
# no 1 00175_jul23.wav
# no 1 00277_jul23.wav
# no 1 00451_jul23.wav
# no 1 00423_jul20.wav
# no 1 00053_jul23.wav
# no 1 00184_jul09.wav
# no 1 00351_jul24.wav
# no 1 00419_jul23.wav
# no 1 00066_jul20.wav
# no 1 00335_jul20.wav
# no 1 00289_jul23.wav
# no 1 00504_jul24.wav
# no 1 00471_jul24.wav
# no 1 00113_jul23.wav
# no 1 00009_jul23.wav
# no 1 00510_jul24.wav
# no 1 00414_jul23.wav
# no 1 00157_jul23.wav
# no 1 00428_jul24.wav
# no 1 00409_jul20.wav
# no 1 00335_jul24.wav
# no 1 00396_jul23.wav
# no 1 00256_jul23.wav
# no 1 00433_jul24.wav
# no 1 00538_jul24.wav
# no 1 00387_jul24.wav
# no 1 00169_jul09.wav
# no 1 00343_jul24.wav
# no 1 00195_jul24.wav
# no 1 00421_jul23.wav
# no 1 00352_jul24.wav
# no 1 00034_jul09.wav
# no 1 00103_jul24.wav
# no 1 00113_jul24.wav
# no 1 00173_jul20.wav
# no 1 00074_jul23.wav
# no 1 00164_jul09.wav
# no 1 00006_jul24.wav
# no 1 00403_jul20.wav
# no 1 00605_jul24.wav
# no 1 00518_jul20.wav
# no 1 00132_jul09.wav
# no 1 00506_jul20.wav
# no 1 00542_jul23.wav
# no 1 00434_jul23.wav
# no 1 00173_jul09.wav
# no 1 00268_jul23.wav
# no 1 00166_jul20.wav
# no 1 00297_jul24.wav
# no 1 00256_jul20.wav
# no 1 00370_jul24.wav
# no 1 00108_jul09.wav
# no 1 00055_jul23.wav
# no 1 00022_jul20.wav
# no 1 00014_jul24.wav
# no 1 00435_jul20.wav
# no 1 00377_jul20.wav
# no 1 00063_jul09.wav
# no 1 00447_jul20.wav
# no 1 00576_jul24.wav
# no 1 00293_jul24.wav
# no 1 00005_jul20.wav
# no 1 00020_jul09.wav
# no 1 00212_jul20.wav
# no 1 00078_jul23.wav
# no 1 00213_jul24.wav
# no 1 00160_jul24.wav
# no 1 00151_jul20.wav
# no 1 00168_jul09.wav
# no 1 00500_jul23.wav
# no 1 00317_jul24.wav
# no 1 00034_jul20.wav
# no 1 00069_jul23.wav
# no 1 00550_jul23.wav
# no 1 00077_jul24.wav
# no 1 00501_jul23.wav
# no 1 00460_jul24.wav
# no 1 00276_jul20.wav
# no 1 00400_jul23.wav
# no 1 00495_jul20.wav
# no 1 00360_jul20.wav
# no 1 00077_jul09.wav
# no 1 00033_jul23.wav
# no 1 00098_jul24.wav
# no 1 00456_jul24.wav
# no 1 00328_jul24.wav
# no 1 00171_jul24.wav
# no 1 00523_jul24.wav
# no 1 00142_jul23.wav
# no 1 00114_jul20.wav
# no 1 00103_jul23.wav
# no 1 00238_jul20.wav
# no 1 00128_jul23.wav
# no 1 00054_jul09.wav
# no 1 00201_jul09.wav
# no 1 00067_jul23.wav
# no 1 00533_jul24.wav
# no 1 00098_jul23.wav
# no 1 00460_jul23.wav
# no 1 00570_jul24.wav
# no 1 00543_jul24.wav
# no 1 00088_jul24.wav
# no 1 00478_jul24.wav
# no 1 00554_jul24.wav
# no 1 00156_jul24.wav
# no 1 00557_jul20.wav
# no 1 00488_jul24.wav
# no 1 00176_jul20.wav
# no 1 00185_jul20.wav
# no 1 00033_jul24.wav
# no 1 00051_jul23.wav
# no 1 00095_jul09.wav
# no 1 00408_jul20.wav
# no 1 00254_jul20.wav
# no 1 00145_jul23.wav
# no 1 00272_jul20.wav
# no 1 00280_jul23.wav
# no 1 00006_jul23.wav
# no 1 00164_jul24.wav
# no 1 00152_jul09.wav
# no 1 00568_jul20.wav
# no 1 00361_jul24.wav
# no 1 00380_jul20.wav
# no 1 00263_jul20.wav
# no 1 00521_jul23.wav
# no 1 00039_jul23.wav
# no 1 00176_jul09.wav
# no 1 00022_jul24.wav
# no 1 00091_jul20.wav
# no 1 00417_jul23.wav
# no 1 00128_jul09.wav
# no 1 00326_jul23.wav
# no 1 00329_jul20.wav
# no 1 00449_jul23.wav
# no 1 00536_jul23.wav
# no 1 00588_jul24.wav
# no 1 00253_jul24.wav
# no 1 00601_jul24.wav
# no 1 00209_jul24.wav
# no 1 00025_jul24.wav
# no 1 00608_jul24.wav
# no 1 00232_jul24.wav
# no 1 00036_jul23.wav
# no 1 00018_jul09.wav
# no 1 00610_jul24.wav
# no 1 00177_jul09.wav
# no 1 00490_jul24.wav
# no 1 00307_jul23.wav
# no 1 00235_jul20.wav
# no 1 00007_jul24.wav
# no 1 00114_jul09.wav
# no 1 00138_jul09.wav
# no 1 00505_jul20.wav
# no 1 00229_jul23.wav
# no 1 00078_jul20.wav
# no 1 00383_jul23.wav
# no 1 00054_jul24.wav
# no 1 00515_jul24.wav
# no 1 00353_jul20.wav
# no 1 00006_jul20.wav
# no 1 00137_jul09.wav
# no 1 00244_jul20.wav
# no 1 00292_jul23.wav
# no 1 00287_jul20.wav
# no 1 00294_jul20.wav
# no 1 00403_jul24.wav
# no 1 00372_jul23.wav
# no 1 00013_jul24.wav
# no 1 00346_jul23.wav
# no 1 00240_jul23.wav
# no 1 00104_jul23.wav
# no 1 00049_jul20.wav
# no 1 00036_jul09.wav
# no 1 00378_jul24.wav
# no 1 00182_jul23.wav
# no 1 00041_jul20.wav
# no 1 00144_jul23.wav
# no 1 00461_jul23.wav
# no 1 00246_jul23.wav
# no 1 00544_jul20.wav
# no 1 00443_jul24.wav
# no 1 00424_jul23.wav
# no 1 00341_jul20.wav
# no 1 00007_jul23.wav
# no 1 00212_jul24.wav
# no 1 00301_jul23.wav
# no 1 00151_jul23.wav
# no 1 00243_jul23.wav
# no 1 00134_jul24.wav
# no 1 00031_jul09.wav
# no 1 00452_jul20.wav
# no 1 00416_jul24.wav
# no 1 00270_jul23.wav
# no 1 00130_jul24.wav
# no 1 00127_jul09.wav
# no 1 00534_jul20.wav
# no 1 00120_jul20.wav
# no 1 00052_jul23.wav
# no 1 00408_jul23.wav
# no 1 00517_jul20.wav
# no 1 00266_jul24.wav
# no 1 00202_jul09.wav
# no 1 00091_jul24.wav
# no 1 00039_jul20.wav
# no 1 00089_jul20.wav
# no 1 00015_jul23.wav
# no 1 00025_jul23.wav
# no 1 00122_jul23.wav
# no 1 00000_jul23.wav
# no 1 00115_jul20.wav
# no 1 00008_jul09.wav
# no 1 00158_jul24.wav
# no 1 00432_jul24.wav
# no 1 00537_jul23.wav
# no 1 00372_jul24.wav
# no 1 00478_jul20.wav
# no 1 00079_jul23.wav
# no 1 00262_jul23.wav
# no 1 00314_jul24.wav
# no 1 00094_jul09.wav
# no 1 00465_jul20.wav
# no 1 00318_jul23.wav
# no 1 00346_jul20.wav
# no 1 00188_jul20.wav
# no 1 00066_jul09.wav
# no 1 00479_jul24.wav
# no 1 00139_jul23.wav
# no 1 00384_jul24.wav
# no 1 00522_jul20.wav
# no 1 00118_jul23.wav
# no 1 00021_jul09.wav
# no 1 00133_jul24.wav
# no 1 00503_jul24.wav
# no 1 00092_jul09.wav
# no 1 00050_jul23.wav
# no 1 00089_jul23.wav
# no 1 00288_jul20.wav
# no 1 00415_jul24.wav
# no 1 00486_jul24.wav
# no 1 00293_jul23.wav
# no 1 00056_jul20.wav
# no 1 00614_jul24.wav
# no 1 00505_jul23.wav
# no 1 00308_jul24.wav
# no 1 00158_jul23.wav
# no 1 00545_jul23.wav
# no 1 00266_jul20.wav
# no 1 00079_jul20.wav
# no 1 00480_jul24.wav
# no 1 00061_jul09.wav
# no 1 00321_jul24.wav
# no 1 00080_jul20.wav
# no 1 00102_jul20.wav
# no 1 00512_jul23.wav
# no 1 00207_jul23.wav
# no 1 00100_jul23.wav
# no 1 00143_jul24.wav
# no 1 00386_jul24.wav
# no 1 00263_jul24.wav
# no 1 00612_jul24.wav
# no 1 00321_jul20.wav
# no 1 00457_jul24.wav
# no 1 00530_jul20.wav
# no 1 00436_jul24.wav
# no 1 00002_jul20.wav
# no 1 00213_jul23.wav
# no 1 00274_jul23.wav
# no 1 00009_jul20.wav
# no 1 00100_jul24.wav
# no 1 00094_jul20.wav
# no 1 00125_jul23.wav
# no 1 00057_jul20.wav
# no 1 00188_jul09.wav
# no 1 00213_jul20.wav
# no 1 00522_jul23.wav
# no 1 00375_jul20.wav
# no 1 00047_jul24.wav
# no 1 00135_jul09.wav
# no 1 00181_jul23.wav
# no 1 00127_jul23.wav
# no 1 00270_jul24.wav
# no 1 00541_jul24.wav
# no 1 00209_jul23.wav
# no 1 00021_jul20.wav
# no 1 00236_jul24.wav
# no 1 00125_jul09.wav
# no 1 00398_jul23.wav
# no 1 00174_jul09.wav
# no 1 00243_jul20.wav
# no 1 00280_jul20.wav
# no 1 00391_jul24.wav
# no 1 00489_jul24.wav
# no 1 00130_jul20.wav
# no 1 00037_jul24.wav
# no 1 00111_jul23.wav
# no 1 00225_jul24.wav
# no 1 00157_jul24.wav
# no 1 00148_jul09.wav
# no 1 00004_jul20.wav
# no 1 00363_jul20.wav
# no 1 00410_jul24.wav
# no 1 00058_jul24.wav
# no 1 00157_jul20.wav
# no 1 00356_jul24.wav
# no 1 00369_jul24.wav
# no 1 00034_jul23.wav
# no 1 00001_jul20.wav
# no 1 00355_jul20.wav
# no 1 00104_jul20.wav
# no 1 00036_jul24.wav
# no 1 00121_jul09.wav
# no 1 00306_jul23.wav
# no 1 00454_jul20.wav
# no 1 00278_jul23.wav
# no 1 00240_jul20.wav
# no 1 00448_jul24.wav
# no 1 00511_jul24.wav
# no 1 00024_jul09.wav
# no 1 00274_jul24.wav
# no 1 00291_jul23.wav
# no 1 00009_jul09.wav
# no 1 00118_jul20.wav
# no 1 00181_jul20.wav
# no 1 00219_jul24.wav
# no 1 00013_jul09.wav
# no 1 00239_jul20.wav
# no 1 00537_jul24.wav
# no 1 00369_jul20.wav
# no 1 00533_jul20.wav
# no 1 00125_jul20.wav
# no 1 00106_jul24.wav
# no 1 00366_jul20.wav
# no 1 00435_jul24.wav
# no 1 00177_jul23.wav
# no 1 00468_jul23.wav
# no 1 00547_jul24.wav
# no 1 00156_jul09.wav
# no 1 00223_jul24.wav
# no 1 00166_jul23.wav
# no 1 00527_jul23.wav
# no 1 00308_jul20.wav
# no 1 00440_jul23.wav
# no 1 00085_jul24.wav
# no 1 00286_jul20.wav
# no 1 00116_jul23.wav
# no 1 00138_jul24.wav
# no 1 00145_jul09.wav
# no 1 00547_jul20.wav
# no 1 00357_jul24.wav
# no 1 00562_jul24.wav
# no 1 00008_jul23.wav
# no 1 00373_jul23.wav
# no 1 00376_jul23.wav
# no 1 00241_jul20.wav
# no 1 00104_jul24.wav
# no 1 00091_jul09.wav
# no 1 00454_jul23.wav
# no 1 00099_jul20.wav
# no 1 00199_jul20.wav
# no 1 00535_jul23.wav
# no 1 00119_jul23.wav
# no 1 00130_jul23.wav
# no 1 00471_jul20.wav
# no 1 00357_jul20.wav
# no 1 00294_jul23.wav
# no 1 00543_jul20.wav
# no 1 00375_jul24.wav
# no 1 00111_jul20.wav
# no 1 00046_jul23.wav
# no 1 00278_jul20.wav
# no 1 00113_jul09.wav
# no 1 00176_jul23.wav
# no 1 00192_jul09.wav
# no 1 00422_jul20.wav
# no 1 00168_jul20.wav
# no 1 00338_jul23.wav
# no 1 00154_jul23.wav
# no 1 00260_jul23.wav
# no 1 00048_jul24.wav
# no 1 00085_jul09.wav
# no 1 00551_jul20.wav
# no 1 00403_jul23.wav
# no 1 00453_jul20.wav
# no 1 00184_jul20.wav
# no 1 00061_jul20.wav
# no 1 00116_jul24.wav
# no 1 00302_jul23.wav
# no 1 00514_jul23.wav
# no 1 00175_jul09.wav
# no 1 00440_jul24.wav
# no 1 00076_jul20.wav
# no 1 00203_jul24.wav
# no 1 00226_jul24.wav
# no 1 00136_jul23.wav
# no 1 00216_jul20.wav
# no 1 00042_jul20.wav
# no 1 00386_jul23.wav
# no 1 00147_jul09.wav
# no 1 00323_jul24.wav
# no 1 00218_jul20.wav
# no 1 00135_jul23.wav
# no 1 00173_jul24.wav
# no 1 00453_jul23.wav
# no 1 00015_jul24.wav
# no 1 00060_jul09.wav
# no 1 00099_jul09.wav
# no 1 00466_jul20.wav
# no 1 00561_jul24.wav
# no 1 00032_jul09.wav
# no 1 00478_jul23.wav
# no 1 00449_jul20.wav
# no 1 00232_jul23.wav
# no 1 00513_jul20.wav
# no 1 00462_jul23.wav
# no 1 00429_jul23.wav
# no 1 00179_jul20.wav
# no 1 00450_jul20.wav
# no 1 00295_jul24.wav
# no 1 00044_jul23.wav
# no 1 00187_jul23.wav
# no 1 00370_jul20.wav
# no 1 00060_jul23.wav
# no 1 00176_jul24.wav
# no 1 00179_jul23.wav
# no 1 00338_jul24.wav
# no 1 00310_jul23.wav
# no 1 00124_jul24.wav
# no 1 00429_jul24.wav
# no 1 00145_jul24.wav
# no 1 00265_jul24.wav
# no 1 00253_jul20.wav
# no 1 00095_jul24.wav
# no 1 00203_jul20.wav
# no 1 00327_jul24.wav
# no 1 00106_jul09.wav
# no 1 00084_jul20.wav
# no 1 00064_jul24.wav
# no 1 00254_jul23.wav
# no 1 00385_jul24.wav
# no 1 00155_jul24.wav
# no 1 00034_jul24.wav
# no 1 00289_jul24.wav
# no 1 00228_jul20.wav
# no 1 00043_jul09.wav
# no 1 00112_jul09.wav
# no 1 00539_jul24.wav
# no 1 00000_jul24.wav
# no 1 00446_jul23.wav
# no 1 00073_jul09.wav
# no 1 00054_jul23.wav
# no 1 00290_jul20.wav
# no 1 00159_jul20.wav
# no 1 00089_jul09.wav
# no 1 00380_jul24.wav
# no 1 00395_jul24.wav
# no 1 00290_jul24.wav
# no 1 00217_jul20.wav
# no 1 00135_jul20.wav
# no 1 00455_jul20.wav
# no 1 00585_jul24.wav
# no 1 00271_jul24.wav
# no 1 00113_jul20.wav
# no 1 00530_jul23.wav
# no 1 00013_jul20.wav
# no 1 00102_jul23.wav
# no 1 00219_jul20.wav
# no 1 00103_jul09.wav
# no 1 00152_jul20.wav
# no 1 00367_jul20.wav
# no 1 00190_jul23.wav
# no 1 00060_jul24.wav
# no 1 00046_jul24.wav
# no 1 00385_jul23.wav
# no 1 00477_jul24.wav
# no 1 00402_jul24.wav
# no 1 00379_jul24.wav
# no 1 00153_jul09.wav
# no 1 00020_jul20.wav
# no 1 00314_jul20.wav
# no 1 00059_jul23.wav
# no 1 00241_jul24.wav
# no 1 00138_jul23.wav
# no 1 00513_jul23.wav
# no 1 00448_jul23.wav
# no 1 00503_jul20.wav
# no 1 00178_jul24.wav
# no 1 00328_jul20.wav
# no 1 00520_jul20.wav
# no 1 00469_jul23.wav
# no 1 00319_jul24.wav
# no 1 00388_jul23.wav
# no 1 00481_jul20.wav
# no 1 00099_jul24.wav
# no 1 00409_jul23.wav
# no 1 00121_jul24.wav
# no 1 00039_jul09.wav
# no 1 00413_jul20.wav
# no 1 00347_jul23.wav
# no 1 00296_jul23.wav
# no 1 00191_jul20.wav
# no 1 00018_jul23.wav
# no 1 00136_jul20.wav
# no 1 00161_jul09.wav
# no 1 00481_jul24.wav
# no 1 00250_jul24.wav
# no 1 00275_jul23.wav
# no 1 00437_jul23.wav
# no 1 00506_jul23.wav
# no 1 00414_jul24.wav
# no 1 00118_jul24.wav
# no 1 00428_jul23.wav
# no 1 00108_jul23.wav
# no 1 00603_jul24.wav
# no 1 00443_jul23.wav
# no 1 00202_jul23.wav
# no 1 00058_jul09.wav
# no 1 00615_jul24.wav
# no 1 00447_jul24.wav
# no 1 00415_jul20.wav
# no 1 00442_jul23.wav
# no 1 00488_jul20.wav
# no 1 00412_jul20.wav
# no 1 00170_jul20.wav
# no 1 00075_jul23.wav
# no 1 00105_jul09.wav
# no 1 00337_jul24.wav
# no 1 00430_jul23.wav
# no 1 00300_jul23.wav
# no 1 00386_jul20.wav
# no 1 00319_jul23.wav
# no 1 00461_jul24.wav
# no 1 00507_jul23.wav
# no 1 00076_jul23.wav
# no 1 00398_jul24.wav
# no 1 00059_jul24.wav
# no 1 00168_jul23.wav
# no 1 00354_jul24.wav
# no 1 00526_jul20.wav
# no 1 00305_jul23.wav
# no 1 00462_jul20.wav
# no 1 00321_jul23.wav
# no 1 00405_jul23.wav
# no 1 00553_jul20.wav
# no 1 00407_jul20.wav
# no 1 00473_jul23.wav
# no 1 00532_jul23.wav
# no 1 00202_jul24.wav
# no 1 00341_jul24.wav
# no 1 00214_jul23.wav
# no 1 00389_jul24.wav
# no 1 00012_jul24.wav
# no 1 00218_jul24.wav
# no 1 00064_jul23.wav
# no 1 00370_jul23.wav
# no 1 00163_jul24.wav
# no 1 00578_jul24.wav
# no 1 00061_jul24.wav
# no 1 00344_jul20.wav
# no 1 00309_jul20.wav
# no 1 00019_jul09.wav
# no 1 00017_jul23.wav
# no 1 00304_jul23.wav
# no 1 00251_jul20.wav
# no 1 00037_jul20.wav
# no 1 00110_jul20.wav
# no 1 00267_jul23.wav
# no 1 00518_jul23.wav
# no 1 00544_jul23.wav
# no 1 00382_jul24.wav
# no 1 00064_jul20.wav
# no 1 00209_jul20.wav
# no 1 00462_jul24.wav
# no 1 00016_jul20.wav
# no 1 00058_jul23.wav
# no 1 00299_jul23.wav
# no 1 00235_jul24.wav
# no 1 00509_jul20.wav
# no 1 00320_jul24.wav
# no 1 00331_jul24.wav
# no 1 00404_jul20.wav
# no 1 00267_jul24.wav
# no 1 00489_jul20.wav
# no 1 00303_jul23.wav
# no 1 00072_jul09.wav
# no 1 00123_jul23.wav
# no 1 00014_jul23.wav
# no 1 00526_jul24.wav
# no 1 00163_jul09.wav
# no 1 00336_jul24.wav
# no 1 00152_jul23.wav
# no 1 00295_jul23.wav
# no 1 00027_jul20.wav
# no 1 00418_jul23.wav
# no 1 00523_jul20.wav
# no 1 00458_jul23.wav
# no 1 00392_jul23.wav
# no 1 00447_jul23.wav
# no 1 00203_jul23.wav
# no 1 00053_jul24.wav
# no 1 00043_jul24.wav
# no 1 00028_jul20.wav
# no 1 00160_jul09.wav
# no 1 00065_jul24.wav
# no 1 00466_jul23.wav
# no 1 00004_jul24.wav
# no 1 00023_jul09.wav
# no 1 00006_jul09.wav
# no 1 00256_jul24.wav
# no 1 00471_jul23.wav
# no 1 00538_jul23.wav
# no 1 00310_jul20.wav
# no 1 00325_jul24.wav
# no 1 00074_jul20.wav
# no 1 00600_jul24.wav
# no 1 00381_jul20.wav
# no 1 00086_jul23.wav
# no 1 00056_jul24.wav
# no 1 00558_jul20.wav
# no 1 00517_jul24.wav
# no 1 00170_jul23.wav
# no 1 00445_jul20.wav
# no 1 00545_jul24.wav
# no 1 00195_jul09.wav
# no 1 00492_jul24.wav
# no 1 00201_jul23.wav
# no 1 00252_jul24.wav
# no 1 00087_jul09.wav
# no 1 00414_jul20.wav
# no 1 00139_jul24.wav
# no 1 00002_jul09.wav
# no 1 00299_jul20.wav
# no 1 00065_jul09.wav
# no 1 00491_jul24.wav
# no 1 00432_jul20.wav
# no 1 00037_jul09.wav
# no 1 00516_jul20.wav
# no 1 00242_jul20.wav
# no 1 00199_jul09.wav
# no 1 00105_jul23.wav
# no 1 00546_jul23.wav
# no 1 00136_jul09.wav
# no 1 00190_jul20.wav
# no 1 00114_jul23.wav
# no 1 00201_jul20.wav
# no 1 00296_jul24.wav
# no 1 00496_jul23.wav
# no 1 00604_jul24.wav
# no 1 00052_jul09.wav
# no 1 00323_jul20.wav
# no 1 00191_jul23.wav
# no 1 00141_jul24.wav
# no 1 00092_jul20.wav
# no 1 00557_jul24.wav
# no 1 00142_jul24.wav
# no 1 00360_jul24.wav
# no 1 00330_jul24.wav
# no 1 00228_jul24.wav
# no 1 00177_jul24.wav
# no 1 00371_jul24.wav
# no 1 00565_jul20.wav
# no 1 00111_jul24.wav
# no 1 00432_jul23.wav
# no 1 00325_jul23.wav
# no 1 00486_jul20.wav
# no 1 00266_jul23.wav
# no 1 00159_jul24.wav
# no 1 00554_jul20.wav
# no 1 00155_jul09.wav
# no 1 00206_jul23.wav
# no 1 00529_jul23.wav
# no 1 00180_jul20.wav
# no 1 00017_jul09.wav
# no 1 00003_jul24.wav
# no 1 00274_jul20.wav
# no 1 00355_jul24.wav
# no 1 00329_jul23.wav
# no 1 00035_jul09.wav
# no 1 00411_jul23.wav
# no 1 00496_jul24.wav
# no 1 00148_jul24.wav
# no 1 00456_jul20.wav
# no 1 00196_jul24.wav
# no 1 00561_jul20.wav
# no 1 00110_jul09.wav
# no 1 00543_jul23.wav
# no 1 00119_jul24.wav
# no 1 00047_jul23.wav
# no 1 00479_jul20.wav
# no 1 00564_jul24.wav
# no 1 00177_jul20.wav
# no 1 00534_jul23.wav
# no 1 00562_jul20.wav
# no 1 00363_jul24.wav
# no 1 00071_jul23.wav
# no 1 00108_jul20.wav
# no 1 00372_jul20.wav
# no 1 00012_jul23.wav
# no 1 00407_jul23.wav
# no 1 00033_jul20.wav
# no 1 00185_jul24.wav
# no 1 00108_jul24.wav
# no 1 00511_jul23.wav
# no 1 00223_jul20.wav
# no 1 00356_jul20.wav
# no 1 00265_jul20.wav
# no 1 00257_jul20.wav
# no 1 00439_jul23.wav
# no 1 00081_jul23.wav
# no 1 00283_jul20.wav
# no 1 00606_jul24.wav
# no 1 00511_jul20.wav
# no 1 00147_jul24.wav
# no 1 00089_jul24.wav
# no 1 00535_jul20.wav
# no 1 00317_jul23.wav
# no 1 00320_jul20.wav
# no 1 00528_jul20.wav
# no 1 00134_jul20.wav
# no 1 00145_jul20.wav
# no 1 00045_jul09.wav
# no 1 00062_jul23.wav
# no 1 00366_jul23.wav
# no 1 00470_jul24.wav
# no 1 00287_jul23.wav
# no 1 00602_jul24.wav
# no 1 00367_jul23.wav
# no 1 00210_jul20.wav
# no 1 00563_jul20.wav
# no 1 00582_jul24.wav
# no 1 00179_jul24.wav
# no 1 00316_jul23.wav
# no 1 00485_jul20.wav
# no 1 00464_jul24.wav
# no 1 00494_jul23.wav
# no 1 00053_jul09.wav
# no 1 00520_jul23.wav
# no 1 00262_jul20.wav
# no 1 00272_jul23.wav
# no 1 00105_jul20.wav
# no 1 00392_jul24.wav
# no 1 00282_jul24.wav
# no 1 00044_jul20.wav
# no 1 00518_jul24.wav
# no 1 00396_jul20.wav
# no 1 00057_jul24.wav
# no 1 00141_jul20.wav
# no 1 00026_jul23.wav
# no 1 00465_jul23.wav
# no 1 00014_jul20.wav
# no 1 00220_jul23.wav
# no 1 00348_jul20.wav
# no 1 00225_jul20.wav
# no 1 00376_jul24.wav
# no 1 00514_jul20.wav
# no 1 00541_jul23.wav
# no 1 00283_jul24.wav
# no 1 00033_jul09.wav
# no 1 00077_jul20.wav
# no 1 00180_jul09.wav
# no 1 00406_jul20.wav
# no 1 00329_jul24.wav
# no 1 00239_jul24.wav
# no 1 00030_jul24.wav
# no 1 00024_jul24.wav
# no 1 00036_jul20.wav
# no 1 00424_jul20.wav
# no 1 00512_jul20.wav
# no 1 00215_jul20.wav
# no 1 00617_jul24.wav
# no 1 00404_jul24.wav
# no 1 00340_jul23.wav
# no 1 00395_jul20.wav
# no 1 00008_jul20.wav
# no 1 00137_jul20.wav
# no 1 00314_jul23.wav
# no 1 00530_jul24.wav
# no 1 00226_jul23.wav
# no 1 00237_jul23.wav
# no 1 00556_jul24.wav
# no 1 00313_jul24.wav
# no 1 00073_jul23.wav
# no 1 00249_jul24.wav
# no 1 00464_jul23.wav
# no 1 00151_jul09.wav
# no 1 00548_jul24.wav
# no 1 00240_jul24.wav
# no 1 00301_jul24.wav
# no 1 00248_jul20.wav
# no 1 00180_jul23.wav
# no 1 00130_jul09.wav
# no 1 00536_jul20.wav
# no 1 00000_jul09.wav
# no 1 00137_jul24.wav
# no 1 00312_jul20.wav
# no 1 00286_jul23.wav
# no 1 00088_jul23.wav
# no 1 00183_jul24.wav
# no 1 00198_jul24.wav
# no 1 00060_jul20.wav
# no 1 00226_jul20.wav
# no 1 00183_jul20.wav
# no 1 00402_jul23.wav
# no 1 00517_jul23.wav
# no 1 00389_jul20.wav
# no 1 00483_jul20.wav
# no 1 00591_jul24.wav
# no 1 00317_jul20.wav
# no 1 00264_jul24.wav
# no 1 00008_jul24.wav
# no 1 00420_jul24.wav
# no 1 00010_jul20.wav
# no 1 00059_jul20.wav
# no 1 00070_jul09.wav
# no 1 00310_jul24.wav
# no 1 00011_jul20.wav
# no 1 00131_jul09.wav
# no 1 00123_jul20.wav
# no 1 00257_jul24.wav
# no 1 00162_jul23.wav
# no 1 00420_jul23.wav
# no 1 00140_jul24.wav
# no 1 00231_jul24.wav
# no 1 00297_jul20.wav
# no 1 00234_jul24.wav
# no 1 00261_jul24.wav
# no 1 00068_jul24.wav
# no 1 00135_jul24.wav
# no 1 00469_jul20.wav
# no 1 00097_jul09.wav
# no 1 00252_jul20.wav
# no 1 00510_jul23.wav
# no 1 00021_jul23.wav
# no 1 00333_jul24.wav
# no 1 00021_jul24.wav
# no 1 00126_jul24.wav
# no 1 00397_jul24.wav
# no 1 00015_jul09.wav
# no 1 00085_jul23.wav
# no 1 00198_jul20.wav
# no 1 00391_jul20.wav
# no 1 00418_jul20.wav
# no 1 00172_jul09.wav
# no 1 00003_jul20.wav
# no 1 00122_jul09.wav
# no 1 00435_jul23.wav
# no 1 00026_jul20.wav
# no 1 00285_jul20.wav
# no 1 00484_jul23.wav
# no 1 00428_jul20.wav
# no 1 00238_jul24.wav
# no 1 00186_jul09.wav
# no 1 00566_jul24.wav
# no 1 00366_jul24.wav
# no 1 00201_jul24.wav
# no 1 00079_jul24.wav
# no 1 00497_jul24.wav
# no 1 00199_jul23.wav
# no 1 00411_jul24.wav
# no 1 00081_jul20.wav
# no 1 00030_jul23.wav
# no 1 00009_jul24.wav
# no 1 00609_jul24.wav
# no 1 00299_jul24.wav
# no 1 00380_jul23.wav
# no 1 00410_jul23.wav
# no 1 00083_jul23.wav
# no 1 00257_jul23.wav
# no 1 00004_jul23.wav
# no 1 00120_jul23.wav
# no 1 00193_jul23.wav
# no 1 00150_jul09.wav
# no 1 00083_jul24.wav
# no 1 00559_jul24.wav
# no 1 00421_jul20.wav
# no 1 00139_jul20.wav
# no 1 00098_jul09.wav
# no 1 00194_jul23.wav
# no 1 00504_jul23.wav
# no 1 00182_jul24.wav
# no 1 00360_jul23.wav
# no 1 00032_jul24.wav
# no 1 00020_jul24.wav
# no 1 00285_jul23.wav
# no 1 00400_jul24.wav
# no 1 00288_jul24.wav
# no 1 00378_jul23.wav
# no 1 00287_jul24.wav
# no 1 00200_jul24.wav
# no 1 00090_jul24.wav
# no 1 00501_jul24.wav
# no 1 00281_jul23.wav
# no 1 00187_jul24.wav
# no 1 00253_jul23.wav
# no 1 00491_jul23.wav
# no 1 00406_jul23.wav
# no 1 00214_jul20.wav
# no 1 00249_jul20.wav
# no 1 00470_jul20.wav
# no 1 00303_jul24.wav
# no 1 00104_jul09.wav
# no 1 00143_jul20.wav
# no 1 00151_jul24.wav
# no 1 00203_jul09.wav
# no 1 00377_jul24.wav
# no 1 00355_jul23.wav
# no 1 00532_jul20.wav
# no 1 00330_jul20.wav
# no 1 00300_jul20.wav
# no 1 00393_jul24.wav
# no 1 00124_jul09.wav
# no 1 00448_jul20.wav
# no 1 00358_jul20.wav
# no 1 00166_jul09.wav
# no 1 00436_jul20.wav
# no 1 00051_jul20.wav
# no 1 00546_jul24.wav
# no 1 00222_jul23.wav
# no 1 00350_jul23.wav
# no 1 00091_jul23.wav
# no 1 00485_jul24.wav
# no 1 00611_jul24.wav
# no 1 00032_jul20.wav
# no 1 00272_jul24.wav
# no 1 00084_jul24.wav
# no 1 00326_jul24.wav
# no 1 00540_jul24.wav
# no 1 00534_jul24.wav
# no 1 00264_jul20.wav
# no 1 00117_jul24.wav
# no 1 00044_jul24.wav
# no 1 00067_jul24.wav
# no 1 00080_jul09.wav
# no 1 00230_jul20.wav
# no 1 00167_jul24.wav
# no 1 00553_jul24.wav
# no 1 00525_jul20.wav
# no 1 00397_jul20.wav
# no 1 00425_jul20.wav
# no 1 00124_jul20.wav
# no 1 00101_jul24.wav
# no 1 00352_jul23.wav
# no 1 00195_jul23.wav
# no 1 00531_jul23.wav
# no 1 00112_jul20.wav
# no 1 00110_jul23.wav
# no 1 00221_jul24.wav
# no 1 00279_jul24.wav
# no 1 00153_jul20.wav
# no 1 00157_jul09.wav
# no 1 00152_jul24.wav
# no 1 00191_jul24.wav
# no 1 00029_jul24.wav
# no 1 00023_jul23.wav
# no 1 00345_jul23.wav
# no 1 00138_jul20.wav
# no 1 00311_jul20.wav
# no 1 00525_jul24.wav
# no 1 00345_jul24.wav
# no 1 00071_jul20.wav
# no 1 00042_jul09.wav
# no 1 00476_jul20.wav
# no 1 00245_jul23.wav
# no 1 00044_jul09.wav
# no 1 00258_jul23.wav
# no 1 00245_jul24.wav
# no 1 00352_jul20.wav
# no 1 00424_jul24.wav
# no 1 00415_jul23.wav
# no 1 00168_jul24.wav
# no 1 00165_jul24.wav
# no 1 00363_jul23.wav
# no 1 00001_jul24.wav
# no 1 00459_jul23.wav
# no 1 00016_jul23.wav
# no 1 00365_jul23.wav
# no 1 00398_jul20.wav
# no 1 00430_jul24.wav
# no 1 00208_jul20.wav
# no 1 00344_jul24.wav
# no 1 00012_jul09.wav
# no 1 00149_jul20.wav
# no 1 00210_jul23.wav
# no 1 00092_jul24.wav
# no 1 00049_jul23.wav
# no 1 00117_jul20.wav
# no 1 00407_jul24.wav
# no 1 00339_jul20.wav
# no 1 00015_jul20.wav
# no 1 00368_jul20.wav
# no 1 00099_jul23.wav
# no 1 00188_jul23.wav
# no 1 00468_jul24.wav
# no 1 00491_jul20.wav
# no 1 00001_jul23.wav
# no 1 00115_jul09.wav
# no 1 00371_jul23.wav
# no 1 00128_jul24.wav
# no 1 00459_jul24.wav
# no 1 00018_jul24.wav
# no 1 00122_jul24.wav
# no 1 00166_jul24.wav
# no 1 00084_jul23.wav
# no 1 00473_jul20.wav
# no 1 00117_jul09.wav
# no 1 00411_jul20.wav
# no 1 00397_jul23.wav
# no 1 00472_jul24.wav
# no 1 00052_jul24.wav
# no 1 00086_jul24.wav
# no 1 00283_jul23.wav
# no 1 00075_jul24.wav
# no 1 00371_jul20.wav
# no 1 00169_jul20.wav
# no 1 00494_jul20.wav
# no 1 00233_jul24.wav
# no 1 00172_jul23.wav
# no 1 00548_jul20.wav
# no 1 00068_jul09.wav
# no 1 00056_jul09.wav
# no 1 00208_jul23.wav
# no 1 00493_jul24.wav
# no 1 00482_jul20.wav
# no 1 00472_jul20.wav
# no 1 00551_jul24.wav
# no 1 00305_jul20.wav
# no 1 00293_jul20.wav
# no 1 00546_jul20.wav
# no 1 00161_jul20.wav
# no 1 00105_jul24.wav
# no 1 00574_jul20.wav
# no 1 00129_jul20.wav
# no 1 00379_jul20.wav
# no 1 00350_jul20.wav
# no 1 00079_jul09.wav
# no 1 00235_jul23.wav
# no 1 00493_jul23.wav
# no 1 00096_jul20.wav
# no 1 00437_jul24.wav
# no 1 00190_jul24.wav
# no 1 00101_jul09.wav
# no 1 00354_jul20.wav
# no 1 00390_jul20.wav
# no 1 00055_jul24.wav
# no 1 00422_jul24.wav
# no 1 00412_jul23.wav
# no 1 00096_jul23.wav
# no 1 00081_jul24.wav
# no 1 00597_jul24.wav
# no 1 00369_jul23.wav
# no 1 00017_jul24.wav
# no 1 00069_jul20.wav
# no 1 00147_jul23.wav
# no 1 00470_jul23.wav
# no 1 00174_jul23.wav
# no 1 00481_jul23.wav
# no 1 00441_jul20.wav
# no 1 00382_jul23.wav
# no 1 00498_jul24.wav
# no 1 00178_jul09.wav
# no 1 00580_jul24.wav
# no 1 00278_jul24.wav
# no 1 00245_jul20.wav
# no 1 00261_jul23.wav
# no 1 00455_jul23.wav
# no 1 00247_jul24.wav
# no 1 00133_jul09.wav
# no 1 00072_jul24.wav
# no 1 00353_jul23.wav
# no 1 00569_jul20.wav
# no 1 00255_jul20.wav
# no 1 00332_jul24.wav
# no 1 00149_jul09.wav
# no 1 00072_jul20.wav
# no 1 00011_jul23.wav
# no 1 00144_jul09.wav
# no 1 00214_jul24.wav
# no 1 00296_jul20.wav
# no 1 00013_jul23.wav
# no 1 00357_jul23.wav
# no 1 00443_jul20.wav
# no 1 00074_jul09.wav
# no 1 00097_jul24.wav
# no 1 00049_jul24.wav
# no 1 00574_jul24.wav
# no 1 00441_jul24.wav
# no 1 00508_jul23.wav
# no 1 00335_jul23.wav
# no 1 00085_jul20.wav
# no 1 00005_jul23.wav
# no 1 00186_jul24.wav
# no 1 00262_jul24.wav
# no 1 00421_jul24.wav
# no 1 00216_jul23.wav
# no 1 00131_jul20.wav
# no 1 00359_jul24.wav
# no 1 00406_jul24.wav
# no 1 00116_jul09.wav
# no 1 00078_jul09.wav
# no 1 00096_jul09.wav
# no 1 00445_jul23.wav
# no 1 00499_jul20.wav
# no 1 00548_jul23.wav
# no 1 00392_jul20.wav
# no 1 00087_jul23.wav
# no 1 00379_jul23.wav
# no 1 00618_jul24.wav
# no 1 00149_jul24.wav
# no 1 00125_jul24.wav
# no 1 00165_jul09.wav
# no 1 00502_jul23.wav
# no 1 00402_jul20.wav
# no 1 00381_jul24.wav
# no 1 00529_jul20.wav
# no 1 00444_jul20.wav
# no 1 00373_jul24.wav
# no 1 00119_jul09.wav
# no 1 00259_jul23.wav
# no 1 00106_jul20.wav
# no 1 00066_jul23.wav
# no 1 00078_jul24.wav
# no 1 00074_jul24.wav
# no 1 00047_jul09.wav
# no 1 00072_jul23.wav
# no 1 00216_jul24.wav
# no 1 00038_jul23.wav
# no 1 00449_jul24.wav
# no 1 00501_jul20.wav
# no 1 00524_jul24.wav
# no 1 00183_jul09.wav
# no 1 00439_jul20.wav
# no 1 00289_jul20.wav
# no 1 00304_jul24.wav
# no 1 00564_jul20.wav
# no 1 00556_jul20.wav
# no 1 00542_jul24.wav
# no 1 00334_jul24.wav
# no 1 00457_jul20.wav
# no 1 00466_jul24.wav
# no 1 00302_jul24.wav
# no 1 00442_jul20.wav
# no 1 00241_jul23.wav
# no 1 00550_jul20.wav
# no 1 00171_jul09.wav
# no 1 00361_jul23.wav
# no 1 00158_jul20.wav
# no 1 00485_jul23.wav
# no 1 00263_jul23.wav
# no 1 00184_jul24.wav
# no 1 00538_jul20.wav
# no 1 00477_jul20.wav
# no 1 00139_jul09.wav
# no 1 00031_jul20.wav
# no 1 00330_jul23.wav
# no 1 00185_jul23.wav
# no 1 00075_jul20.wav
# no 1 00188_jul24.wav
# no 1 00341_jul23.wav
# no 1 00551_jul23.wav
# no 1 00533_jul23.wav
# no 1 00351_jul20.wav
# no 1 00394_jul20.wav
# no 1 00343_jul23.wav
# no 1 00143_jul23.wav
# no 1 00003_jul09.wav
# no 1 00315_jul20.wav
# no 1 00186_jul23.wav
# no 1 00192_jul24.wav
# no 1 00215_jul24.wav
# no 1 00276_jul24.wav
# no 1 00269_jul24.wav
# no 1 00516_jul23.wav
# no 1 00196_jul09.wav
# no 1 00331_jul23.wav
# no 1 00399_jul24.wav
# no 1 00192_jul20.wav
# no 1 00002_jul24.wav
# no 1 00338_jul20.wav
# no 1 00497_jul20.wav
# no 1 00479_jul23.wav
# no 1 00014_jul09.wav
# no 1 00521_jul24.wav
# no 1 00071_jul09.wav
# no 1 00346_jul24.wav
# no 1 00040_jul24.wav
# no 1 00374_jul23.wav
# no 1 00097_jul23.wav
# no 1 00073_jul24.wav
# no 1 00115_jul23.wav
# no 1 00179_jul09.wav
# no 1 00189_jul24.wav
# no 1 00494_jul24.wav
# no 1 00095_jul23.wav
# no 1 00129_jul09.wav
# no 1 00187_jul20.wav
# no 1 00112_jul23.wav
# no 1 00029_jul20.wav
# no 1 00439_jul24.wav
# no 1 00210_jul24.wav
# no 1 00458_jul20.wav
# no 1 00221_jul20.wav
# no 1 00560_jul24.wav
# no 1 00144_jul20.wav
# no 1 00185_jul09.wav
# no 1 00324_jul24.wav
# no 1 00131_jul23.wav
# no 1 00514_jul24.wav
# no 1 00164_jul20.wav
# no 1 00137_jul23.wav
# no 1 00126_jul20.wav
# no 1 00390_jul24.wav
# no 1 00311_jul24.wav
# no 1 00231_jul23.wav
# no 1 00242_jul24.wav
# no 1 00103_jul20.wav
# no 1 00133_jul23.wav
# no 1 00540_jul23.wav
# no 1 00182_jul09.wav
# no 1 00444_jul24.wav
# no 1 00309_jul24.wav
# no 1 00290_jul23.wav
# no 1 00165_jul23.wav
# no 1 00102_jul09.wav
# no 1 00031_jul23.wav
# no 1 00175_jul24.wav
# no 1 00194_jul24.wav
# no 1 00200_jul23.wav
# no 1 00007_jul20.wav
# no 1 00332_jul20.wav
# no 1 00206_jul24.wav
# no 1 00288_jul23.wav
# no 1 00531_jul20.wav
# no 1 00454_jul24.wav
# no 1 00100_jul09.wav
# no 1 00510_jul20.wav
# no 1 00175_jul20.wav
# no 1 00228_jul23.wav
# no 1 00364_jul20.wav
# no 1 00198_jul23.wav
# no 1 00126_jul23.wav
# no 1 00327_jul23.wav
# no 1 00362_jul20.wav
# no 1 00575_jul24.wav
# no 1 00132_jul23.wav
# no 1 00236_jul20.wav
# no 1 00342_jul23.wav
# no 1 00307_jul24.wav
# no 1 00239_jul23.wav
# no 1 00590_jul24.wav
# no 1 00050_jul20.wav
# no 1 00148_jul20.wav
# no 1 00095_jul20.wav
# no 1 00334_jul20.wav
# no 1 00391_jul23.wav
# no 1 00596_jul24.wav
# no 1 00032_jul23.wav
# no 1 00162_jul09.wav
# no 1 00515_jul20.wav
# no 1 00498_jul23.wav
# no 1 00043_jul23.wav
# no 1 00506_jul24.wav
# no 1 00248_jul24.wav
# no 1 00230_jul24.wav
# no 1 00525_jul23.wav
# no 1 00576_jul20.wav
# no 1 00172_jul20.wav
# no 1 00342_jul24.wav
# no 1 00526_jul23.wav
# no 1 00364_jul23.wav
# no 1 00207_jul24.wav
# no 1 00452_jul24.wav
# no 1 00570_jul20.wav
# no 1 00127_jul20.wav
# no 1 00593_jul24.wav
# no 1 00150_jul24.wav
# no 1 00572_jul20.wav
# no 1 00035_jul23.wav
# no 1 00298_jul20.wav
# no 1 00159_jul09.wav
# no 1 00577_jul24.wav
# no 1 00043_jul20.wav
# no 1 00067_jul20.wav
# no 1 00057_jul23.wav
# no 1 00275_jul20.wav
# no 1 00068_jul23.wav
# no 1 00062_jul24.wav
# no 1 00246_jul24.wav
# no 1 00475_jul20.wav
# no 1 00464_jul20.wav
# no 1 00107_jul23.wav
# no 1 00170_jul09.wav
# no 1 00199_jul24.wav
# no 1 00250_jul20.wav
# no 1 00035_jul20.wav
# no 1 00048_jul20.wav
# no 1 00359_jul20.wav
# no 1 00315_jul23.wav
# no 1 00467_jul23.wav
# no 1 00254_jul24.wav
# no 1 00066_jul24.wav
# no 1 00063_jul24.wav
# no 1 00524_jul23.wav
# no 1 00459_jul20.wav
# no 1 00389_jul23.wav
# no 1 00086_jul20.wav
# no 1 00367_jul24.wav
# no 1 00535_jul24.wav
# no 1 00206_jul20.wav
# no 1 00024_jul23.wav
# no 1 00178_jul23.wav
# no 1 00571_jul24.wav
# no 1 00337_jul23.wav
# no 1 00109_jul23.wav
# no 1 00282_jul23.wav
# no 1 00560_jul20.wav
# no 1 00121_jul23.wav
# no 1 00268_jul24.wav
# no 1 00410_jul20.wav
# no 1 00487_jul23.wav
# no 1 00309_jul23.wav
# no 1 00146_jul20.wav
# no 1 00211_jul23.wav
# no 1 00112_jul24.wav
# no 1 00545_jul20.wav
# no 1 00200_jul20.wav
# no 1 00399_jul20.wav
# no 1 00090_jul09.wav
# no 1 00172_jul24.wav
# no 1 00167_jul23.wav
# no 1 00420_jul20.wav
# no 1 00027_jul23.wav
# no 1 00045_jul20.wav
# no 1 00155_jul23.wav
# no 1 00251_jul23.wav
# no 1 00087_jul24.wav
# no 1 00519_jul23.wav
# no 1 00396_jul24.wav
# no 1 00159_jul23.wav
# no 1 00484_jul20.wav
# no 1 00305_jul24.wav
# no 1 00207_jul20.wav
# no 1 00133_jul20.wav
# no 1 00150_jul23.wav
# no 1 00258_jul20.wav
# no 1 00132_jul24.wav
# no 1 00374_jul20.wav
# no 1 00062_jul09.wav
# no 1 00022_jul09.wav
# no 1 00504_jul20.wav
# no 1 00496_jul20.wav
# no 1 00515_jul23.wav
# no 1 00500_jul20.wav
# no 1 00047_jul20.wav
# no 1 00322_jul20.wav
# no 1 00441_jul23.wav
# no 1 00146_jul09.wav
# no 1 00319_jul20.wav
# no 1 00054_jul20.wav
# no 1 00180_jul24.wav
# no 1 00011_jul09.wav
# no 1 00019_jul24.wav
# no 1 00383_jul20.wav
# no 1 00186_jul20.wav
# no 1 00050_jul24.wav
# no 1 00154_jul24.wav
# no 1 00002_jul23.wav
# no 1 00233_jul20.wav
# no 1 00450_jul23.wav
# no 1 00539_jul20.wav
# no 1 00477_jul23.wav
# no 1 00559_jul20.wav
# no 1 00388_jul24.wav
# no 1 00110_jul24.wav
# no 1 00401_jul23.wav
# no 1 00499_jul24.wav
# no 1 00507_jul24.wav
# no 1 00198_jul09.wav
# no 1 00349_jul24.wav
# no 1 00126_jul09.wav
# no 1 00607_jul24.wav
# no 1 00106_jul23.wav
# no 1 00076_jul24.wav
# no 1 00222_jul20.wav
# no 1 00555_jul24.wav
# no 1 00005_jul09.wav
# no 1 00111_jul09.wav
# no 1 00067_jul09.wav
# no 1 00549_jul24.wav
# no 1 00450_jul24.wav
# no 1 00358_jul23.wav
# no 1 00045_jul24.wav
# no 1 00430_jul20.wav
# no 1 00333_jul20.wav
# no 1 00124_jul23.wav
# no 1 00300_jul24.wav
# no 1 00065_jul23.wav
# no 1 00331_jul20.wav
# no 1 00251_jul24.wav
# no 1 00474_jul20.wav
# no 1 00472_jul23.wav
# no 1 00492_jul23.wav
# no 1 00498_jul20.wav
# no 1 00365_jul20.wav
# no 1 00457_jul23.wav
# no 1 00486_jul23.wav
# no 1 00584_jul24.wav
# no 1 00563_jul24.wav
# no 1 00567_jul20.wav
# no 1 00077_jul23.wav
# no 1 00304_jul20.wav
# no 1 00323_jul23.wav
# no 1 00122_jul20.wav
# no 1 00313_jul20.wav
# no 1 00345_jul20.wav
# no 1 00311_jul23.wav
# no 1 00081_jul09.wav
# no 1 00461_jul20.wav
# no 1 00463_jul20.wav
# no 1 00193_jul20.wav
# no 1 00217_jul24.wav
# no 1 00140_jul20.wav
# no 1 00527_jul24.wav
# no 1 00018_jul20.wav
# no 1 00140_jul09.wav
# no 1 00189_jul09.wav
# no 1 00516_jul24.wav
# no 1 00230_jul23.wav
# no 1 00178_jul20.wav
# no 1 00440_jul20.wav
# no 1 00046_jul20.wav
# no 1 00027_jul09.wav
# no 1 00219_jul23.wav
# no 1 00487_jul24.wav
# no 1 00070_jul20.wav
# no 1 00000_jul20.wav
# no 1 00434_jul24.wav
# no 1 00063_jul23.wav
# no 1 00182_jul20.wav
# no 1 00394_jul23.wav
# no 1 00292_jul24.wav
# no 1 00332_jul23.wav
# no 1 00425_jul23.wav
# no 1 00115_jul24.wav
# no 1 00163_jul23.wav
# no 1 00349_jul20.wav
# no 1 00070_jul23.wav
# no 1 00048_jul23.wav
# no 1 00220_jul20.wav
# no 1 00237_jul24.wav
# no 1 00169_jul24.wav
# no 1 00572_jul24.wav
# no 1 00324_jul23.wav
# no 1 00465_jul24.wav
# no 1 00384_jul23.wav
# no 1 00174_jul20.wav
# no 1 00549_jul23.wav
# no 1 00243_jul24.wav
# no 1 00158_jul09.wav
# no 1 00193_jul24.wav
# no 1 00217_jul23.wav
# no 1 00119_jul20.wav
# no 1 00334_jul23.wav
# no 1 00038_jul09.wav
# no 1 00595_jul24.wav
# no 1 00318_jul24.wav
# no 1 00467_jul20.wav
# no 1 00312_jul24.wav
# no 1 00255_jul23.wav
# no 1 00467_jul24.wav
# no 1 00519_jul20.wav
# no 1 00064_jul09.wav
# no 1 00419_jul24.wav
# no 1 00483_jul23.wav
# no 1 00505_jul24.wav
# no 1 00123_jul24.wav
# no 1 00434_jul20.wav
# no 1 00093_jul20.wav
# no 1 00116_jul20.wav
# no 1 00306_jul20.wav
# no 1 00519_jul24.wav
# no 1 00455_jul24.wav
# no 1 00361_jul20.wav
# no 1 00348_jul24.wav
# no 1 00493_jul20.wav
# no 1 00489_jul23.wav
# no 1 00083_jul09.wav
# no 1 00400_jul20.wav
# no 1 00476_jul23.wav
# no 1 00234_jul23.wav
# no 1 00307_jul20.wav
# no 1 00452_jul23.wav
# no 1 00565_jul24.wav
# no 1 00347_jul24.wav
# no 1 00040_jul23.wav
# no 1 00247_jul20.wav
# no 1 00187_jul09.wav
# no 1 00483_jul24.wav
# no 1 00508_jul24.wav
# no 1 00041_jul09.wav
# no 1 00022_jul23.wav
# no 1 00063_jul20.wav
# no 1 00592_jul24.wav
# no 1 00427_jul20.wav
# no 1 00417_jul20.wav
# no 1 00492_jul20.wav
# no 1 00579_jul24.wav
# no 1 00422_jul23.wav
# no 1 00026_jul09.wav
# no 1 00487_jul20.wav
# no 1 00373_jul20.wav
# no 1 00291_jul20.wav
# no 1 00160_jul20.wav
# no 1 00476_jul24.wav
# no 1 00136_jul24.wav
# no 1 00222_jul24.wav
# no 1 00259_jul24.wav
# no 1 00165_jul20.wav
# no 1 00399_jul23.wav
# no 1 00594_jul24.wav
# no 1 00259_jul20.wav
# no 1 00195_jul20.wav
# no 1 00401_jul20.wav
# no 1 00333_jul23.wav
# no 1 00522_jul24.wav
# no 1 00011_jul24.wav
# no 1 00029_jul23.wav
# no 1 00285_jul24.wav
# no 1 00426_jul20.wav
# no 1 00218_jul23.wav
# no 1 00589_jul24.wav
# no 1 00312_jul23.wav
# no 1 00426_jul23.wav
# no 1 00252_jul23.wav
# no 1 00281_jul20.wav
# no 1 00129_jul24.wav
# no 1 00035_jul24.wav
# no 1 00132_jul20.wav
# no 1 00083_jul20.wav
# no 1 00286_jul24.wav
# no 1 00571_jul20.wav
# no 1 00316_jul24.wav
# no 1 00231_jul20.wav
# no 1 00586_jul24.wav
# no 1 00058_jul20.wav
# no 1 00384_jul20.wav
# no 1 00356_jul23.wav
# no 1 00336_jul20.wav
# no 1 00577_jul20.wav
# no 1 00273_jul20.wav
# no 1 00080_jul24.wav
# no 1 00377_jul23.wav
# no 1 00224_jul24.wav
# no 1 00413_jul24.wav
# no 1 00326_jul20.wav
# no 1 00028_jul24.wav
# no 1 00023_jul24.wav
# no 1 00542_jul20.wav
# no 1 00499_jul23.wav
# no 1 00318_jul20.wav
# no 1 00261_jul20.wav
# no 1 00362_jul24.wav
# no 1 00284_jul23.wav
# no 1 00149_jul23.wav
# no 1 00192_jul23.wav
# no 1 00281_jul24.wav
# no 1 00390_jul23.wav
# no 1 00055_jul09.wav
# no 1 00350_jul24.wav
# no 1 00359_jul23.wav
# no 1 00090_jul23.wav
# no 1 00042_jul23.wav
# no 1 00144_jul24.wav
# no 1 00523_jul23.wav
# no 1 00109_jul24.wav
# no 1 00173_jul23.wav
# no 1 00004_jul09.wav
# no 1 00057_jul09.wav
# no 1 00244_jul24.wav
# no 1 00260_jul24.wav
# no 1 00569_jul24.wav
# no 1 00616_jul24.wav
# no 1 00071_jul24.wav
# no 1 00368_jul24.wav
# no 1 00019_jul20.wav
# no 1 00128_jul20.wav
# no 1 00233_jul23.wav
# no 1 00413_jul23.wav
# no 1 00475_jul24.wav
# no 1 00154_jul20.wav
# no 1 00242_jul23.wav
# no 1 00354_jul23.wav
# no 1 00279_jul23.wav
# no 1 00322_jul24.wav
# no 1 00046_jul09.wav
# no 1 00248_jul23.wav
# no 1 00065_jul20.wav
# no 1 00295_jul20.wav
# no 1 00426_jul24.wav
# no 1 00236_jul23.wav
# no 1 00297_jul23.wav
# no 1 00010_jul23.wav
# no 1 00142_jul09.wav
# no 1 00349_jul23.wav
# no 1 00170_jul24.wav
# no 1 00425_jul24.wav
# no 1 00497_jul23.wav
# no 1 00324_jul20.wav
# no 1 00114_jul24.wav
# no 1 00475_jul23.wav
# no 1 00513_jul24.wav
# no 1 00539_jul23.wav
# no 1 00059_jul09.wav
# no 1 00437_jul20.wav
# no 1 00255_jul24.wav
# no 1 00418_jul24.wav
# no 1 00121_jul20.wav
# no 1 00249_jul23.wav
# no 1 00027_jul24.wav
# no 1 00509_jul24.wav
# no 1 00463_jul24.wav
# no 1 00524_jul20.wav
# no 1 00191_jul09.wav
# no 1 00438_jul23.wav
# no 1 00141_jul09.wav
# no 1 00463_jul23.wav
# no 1 00532_jul24.wav
# no 1 00270_jul20.wav
# no 1 00282_jul20.wav
# no 1 00196_jul23.wav
# no 1 00544_jul24.wav
# no 1 00247_jul23.wav
# no 1 00488_jul23.wav
# no 1 00416_jul20.wav
# no 1 00275_jul24.wav
# no 1 00051_jul24.wav
# no 1 00306_jul24.wav
# no 1 00301_jul20.wav
# no 1 00453_jul24.wav
# no 1 00068_jul20.wav
# no 1 00120_jul09.wav
# no 1 00153_jul24.wav
# no 1 00258_jul24.wav
# no 1 00052_jul20.wav
# no 1 00495_jul23.wav
# no 1 00419_jul20.wav
# no 1 00482_jul23.wav
# no 1 00131_jul24.wav
# no 1 00012_jul20.wav
# no 1 00026_jul24.wav
# no 1 00292_jul20.wav
# no 1 00521_jul20.wav
# no 1 00220_jul24.wav
# no 1 00340_jul20.wav
# no 1 00269_jul20.wav
# no 1 00030_jul09.wav
# no 1 00315_jul24.wav
# no 1 00171_jul23.wav
# no 1 00234_jul20.wav
# no 1 00469_jul24.wav
# no 1 00016_jul09.wav
# no 1 00365_jul24.wav
# no 1 00280_jul24.wav
# no 1 00322_jul23.wav
# no 1 00347_jul20.wav
# no 1 00107_jul24.wav
# no 1 00313_jul23.wav
# no 1 00388_jul20.wav
# no 1 00082_jul23.wav
# no 1 00348_jul23.wav
# no 1 00118_jul09.wav
# no 1 00094_jul23.wav
# no 1 00395_jul23.wav
# no 1 00088_jul20.wav
# no 1 00547_jul23.wav
# no 1 00573_jul24.wav
# no 1 00339_jul23.wav
# no 1 00050_jul09.wav
# no 1 00053_jul20.wav
# no 1 00273_jul24.wav
# no 1 00446_jul24.wav
# no 1 00038_jul24.wav
# no 1 00194_jul20.wav
# no 1 00423_jul24.wav
# no 1 00109_jul09.wav
# no 1 00056_jul23.wav
# no 1 00383_jul24.wav
# no 1 00221_jul23.wav
# no 1 00025_jul20.wav
# no 1 00155_jul20.wav
# no 1 00010_jul24.wav
# no 1 00134_jul23.wav
# no 1 00212_jul23.wav
# no 1 00328_jul23.wav
# no 1 00019_jul23.wav
# no 1 00362_jul23.wav
# no 1 00181_jul24.wav
# no 1 00567_jul24.wav
# no 1 00120_jul24.wav
# no 1 00303_jul20.wav
# no 1 00028_jul23.wav
# no 1 00134_jul09.wav
# no 1 00528_jul23.wav
# no 1 00042_jul24.wav
# no 1 00171_jul20.wav
# no 1 00123_jul09.wav
# no 1 00279_jul20.wav
# no 1 00474_jul24.wav
# no 1 00436_jul23.wav
# no 1 00500_jul24.wav
# no 1 00353_jul24.wav
# no 1 00090_jul20.wav
# no 1 00394_jul24.wav
# no 1 00229_jul24.wav
# no 1 00423_jul23.wav
# no 1 00531_jul24.wav
# no 1 00385_jul20.wav
# no 1 00061_jul23.wav
# no 1 00343_jul20.wav
# no 1 00320_jul23.wav
# no 1 00368_jul23.wav
# no 1 00438_jul24.wav
# no 1 00376_jul20.wav
# no 1 00073_jul20.wav
# no 1 00260_jul20.wav
# no 1 00183_jul23.wav
# no 1 00164_jul23.wav
# no 1 00277_jul20.wav
# no 1 00224_jul20.wav
# no 1 00405_jul24.wav
# no 1 00583_jul24.wav
# no 1 00017_jul20.wav
# no 1 00552_jul20.wav
# no 1 00339_jul24.wav
# no 1 00284_jul24.wav
# no 1 00163_jul20.wav
# no 1 00227_jul23.wav
# no 1 00268_jul20.wav
# no 1 00001_jul09.wav
# no 1 00375_jul23.wav
# no 1 00196_jul20.wav
# no 1 00062_jul20.wav
# no 1 00431_jul24.wav
# no 1 00142_jul20.wav
# no 1 00378_jul20.wav
# no 1 00003_jul23.wav
# no 1 00294_jul24.wav
# no 1 00446_jul20.wav
# no 1 00049_jul09.wav
# no 1 00092_jul23.wav
# no 1 00587_jul24.wav
# no 1 00417_jul24.wav
# no 1 00069_jul09.wav
# no 1 00030_jul20.wav
# no 1 00189_jul23.wav
# no 1 00225_jul23.wav
# no 1 00271_jul20.wav
# no 1 00148_jul23.wav
# no 1 00438_jul20.wav
# no 1 00160_jul23.wav
# no 1 00431_jul20.wav
# no 1 00024_jul20.wav
# no 1 00536_jul24.wav
# no 1 00573_jul20.wav
# no 1 00581_jul24.wav
# no 1 00244_jul23.wav
# no 1 00100_jul20.wav
# no 1 00267_jul20.wav
# no 1 00374_jul24.wav
# no 1 00194_jul09.wav
# no 1 00541_jul20.wav
# no 1 00087_jul20.wav
# no 1 00051_jul09.wav
# no 1 00336_jul23.wav
# no 1 00550_jul24.wav
# no 1 00484_jul24.wav
# no 1 00141_jul23.wav
# no 1 00451_jul20.wav
# no 1 00023_jul20.wav
# no 1 00161_jul23.wav
# no 1 00473_jul24.wav
# no 1 00382_jul20.wav
# no 1 00146_jul23.wav
# no 1 00229_jul20.wav
# no 1 00537_jul20.wav
# no 1 00069_jul24.wav
# no 1 00181_jul09.wav
# no 1 00084_jul09.wav
# no 1 00211_jul20.wav
# no 1 00269_jul23.wav
# no 1 00405_jul20.wav
# no 1 00162_jul20.wav
# no 1 00480_jul20.wav
# no 1 00143_jul09.wav
# no 1 00599_jul24.wav
# no 1 00080_jul23.wav
# no 1 00409_jul24.wav
# no 1 00041_jul24.wav
# no 1 00215_jul23.wav
# no 1 00070_jul24.wav
# no 1 00237_jul20.wav
# no 1 00232_jul20.wav
# no 1 00552_jul24.wav
# no 1 00101_jul20.wav
# no 1 00246_jul20.wav
# no 1 00482_jul24.wav
# no 1 00291_jul24.wav
# no 1 00150_jul20.wav
# no 1 00154_jul09.wav
# no 1 00433_jul23.wav
# no 1 00184_jul23.wav
# no 1 00549_jul20.wav
# no 1 00161_jul24.wav
# no 1 00325_jul20.wav
# no 1 00344_jul23.wav
# no 1 00007_jul09.wav
# no 1 00037_jul23.wav
# no 1 00502_jul24.wav
# no 1 00264_jul23.wav
# no 1 00211_jul24.wav
# no 1 00508_jul20.wav
# no 1 00558_jul24.wav
# no 1 00298_jul24.wav
# no 1 00082_jul24.wav
# no 1 00048_jul09.wav
# no 1 00224_jul23.wav
# 1 : stop
# stop 1 00156_jul23.wav
# stop 1 00340_jul24.wav
# stop 1 00427_jul24.wav
# stop 1 00555_jul20.wav
# stop 1 00146_jul24.wav
# stop 1 00308_jul23.wav
# stop 1 00169_jul23.wav
# stop 1 00020_jul23.wav
# stop 1 00093_jul09.wav
# stop 1 00167_jul09.wav
# stop 1 00277_jul24.wav
# stop 1 00613_jul24.wav
# stop 1 00045_jul23.wav
# stop 1 00102_jul24.wav
# stop 1 00566_jul20.wav
# stop 1 00202_jul20.wav
# stop 1 00238_jul23.wav
# stop 1 00227_jul24.wav
# stop 1 00097_jul20.wav
# stop 1 00480_jul23.wav
# stop 1 00393_jul23.wav
# stop 1 00527_jul20.wav
# stop 1 00302_jul20.wav
# stop 1 00140_jul23.wav
# stop 1 00468_jul20.wav
# stop 1 00223_jul23.wav
# stop 1 00039_jul24.wav
# stop 1 00076_jul09.wav
# stop 1 00107_jul20.wav
# stop 1 00503_jul23.wav
# stop 1 00208_jul24.wav
# stop 1 00038_jul20.wav
# stop 1 00490_jul20.wav
# stop 1 00040_jul09.wav
# stop 1 00456_jul23.wav
# stop 1 00156_jul20.wav
# stop 1 00387_jul23.wav
# stop 1 00082_jul20.wav
# stop 1 00540_jul20.wav
# stop 1 00153_jul23.wav
# stop 1 00381_jul23.wav
# stop 1 00337_jul20.wav
# stop 1 00082_jul09.wav
# stop 1 00364_jul24.wav
# stop 1 00167_jul20.wav
# stop 1 00342_jul20.wav
# stop 1 00393_jul20.wav
# stop 1 00585_jul20.wav
# stop 1 00575_jul20.wav
# stop 1 00117_jul23.wav
# stop 1 00041_jul23.wav
# stop 1 00358_jul24.wav
# stop 1 00401_jul24.wav
# stop 1 00129_jul23.wav
# stop 1 00028_jul09.wav
# stop 1 00316_jul20.wav
# stop 1 00093_jul23.wav
# stop 1 00250_jul23.wav
# stop 1 00284_jul20.wav
# stop 1 00086_jul09.wav
# stop 1 00433_jul20.wav
# stop 1 00016_jul24.wav
# stop 1 00404_jul23.wav
# stop 1 00451_jul24.wav
# stop 1 00458_jul24.wav
# stop 1 00474_jul23.wav
# stop 1 00096_jul24.wav
# stop 1 00109_jul20.wav
# stop 1 00075_jul09.wav
# stop 1 00098_jul20.wav
# stop 1 00189_jul20.wav
# stop 1 00598_jul24.wav
# stop 1 00031_jul24.wav
# stop 1 00227_jul20.wav
# stop 1 00127_jul24.wav
# stop 1 00490_jul23.wav
# stop 1 00174_jul24.wav
# stop 1 00298_jul23.wav
# stop 1 00429_jul20.wav
# stop 1 00528_jul24.wav
# stop 1 00416_jul23.wav
# stop 1 00010_jul09.wav
# stop 1 00276_jul23.wav
# stop 1 00529_jul24.wav
# stop 1 00040_jul20.wav
# stop 1 00512_jul24.wav
# stop 1 00101_jul23.wav
# stop 1 00502_jul20.wav
# stop 1 00162_jul24.wav
# stop 1 00147_jul20.wav
# stop 1 00568_jul24.wav
# stop 1 00442_jul24.wav
# stop 1 00351_jul23.wav
# stop 1 00509_jul23.wav
# stop 1 00408_jul24.wav
# stop 1 00495_jul24.wav
# stop 1 00445_jul24.wav
# stop 1 00431_jul23.wav
# stop 1 00273_jul23.wav
# stop 1 00107_jul09.wav
# stop 1 00088_jul09.wav
# stop 1 00327_jul20.wav
# stop 1 00444_jul23.wav
# stop 1 00427_jul23.wav
# stop 1 00055_jul20.wav
# stop 1 00265_jul23.wav
# stop 1 00520_jul24.wav
# stop 1 00025_jul09.wav
# stop 1 00507_jul20.wav
# stop 1 00094_jul24.wav
# stop 1 00093_jul24.wav
# stop 1 00029_jul09.wav
# stop 1 00005_jul24.wav
# stop 1 00460_jul20.wav
# stop 1 00175_jul23.wav
# stop 1 00277_jul23.wav
# stop 1 00451_jul23.wav
# stop 1 00423_jul20.wav
# stop 1 00053_jul23.wav
# stop 1 00184_jul09.wav
# stop 1 00351_jul24.wav
# stop 1 00419_jul23.wav
# stop 1 00066_jul20.wav
# stop 1 00335_jul20.wav
# stop 1 00289_jul23.wav
# stop 1 00504_jul24.wav
# stop 1 00471_jul24.wav
# stop 1 00113_jul23.wav
# stop 1 00009_jul23.wav
# stop 1 00510_jul24.wav
# stop 1 00414_jul23.wav
# stop 1 00157_jul23.wav
# stop 1 00428_jul24.wav
# stop 1 00409_jul20.wav
# stop 1 00335_jul24.wav
# stop 1 00396_jul23.wav
# stop 1 00256_jul23.wav
# stop 1 00433_jul24.wav
# stop 1 00538_jul24.wav
# stop 1 00387_jul24.wav
# stop 1 00169_jul09.wav
# stop 1 00343_jul24.wav
# stop 1 00195_jul24.wav
# stop 1 00421_jul23.wav
# stop 1 00352_jul24.wav
# stop 1 00034_jul09.wav
# stop 1 00103_jul24.wav
# stop 1 00113_jul24.wav
# stop 1 00173_jul20.wav
# stop 1 00074_jul23.wav
# stop 1 00164_jul09.wav
# stop 1 00006_jul24.wav
# stop 1 00559_jul23.wav
# stop 1 00403_jul20.wav
# stop 1 00605_jul24.wav
# stop 1 00518_jul20.wav
# stop 1 00132_jul09.wav
# stop 1 00506_jul20.wav
# stop 1 00542_jul23.wav
# stop 1 00434_jul23.wav
# stop 1 00173_jul09.wav
# stop 1 00268_jul23.wav
# stop 1 00166_jul20.wav
# stop 1 00297_jul24.wav
# stop 1 00256_jul20.wav
# stop 1 00370_jul24.wav
# stop 1 00108_jul09.wav
# stop 1 00055_jul23.wav
# stop 1 00022_jul20.wav
# stop 1 00014_jul24.wav
# stop 1 00435_jul20.wav
# stop 1 00377_jul20.wav
# stop 1 00063_jul09.wav
# stop 1 00447_jul20.wav
# stop 1 00576_jul24.wav
# stop 1 00293_jul24.wav
# stop 1 00005_jul20.wav
# stop 1 00564_jul23.wav
# stop 1 00020_jul09.wav
# stop 1 00212_jul20.wav
# stop 1 00078_jul23.wav
# stop 1 00213_jul24.wav
# stop 1 00160_jul24.wav
# stop 1 00151_jul20.wav
# stop 1 00168_jul09.wav
# stop 1 00500_jul23.wav
# stop 1 00317_jul24.wav
# stop 1 00034_jul20.wav
# stop 1 00069_jul23.wav
# stop 1 00550_jul23.wav
# stop 1 00077_jul24.wav
# stop 1 00501_jul23.wav
# stop 1 00460_jul24.wav
# stop 1 00276_jul20.wav
# stop 1 00400_jul23.wav
# stop 1 00495_jul20.wav
# stop 1 00360_jul20.wav
# stop 1 00077_jul09.wav
# stop 1 00033_jul23.wav
# stop 1 00098_jul24.wav
# stop 1 00456_jul24.wav
# stop 1 00328_jul24.wav
# stop 1 00171_jul24.wav
# stop 1 00523_jul24.wav
# stop 1 00142_jul23.wav
# stop 1 00114_jul20.wav
# stop 1 00103_jul23.wav
# stop 1 00238_jul20.wav
# stop 1 00128_jul23.wav
# stop 1 00054_jul09.wav
# stop 1 00067_jul23.wav
# stop 1 00533_jul24.wav
# stop 1 00098_jul23.wav
# stop 1 00460_jul23.wav
# stop 1 00570_jul24.wav
# stop 1 00543_jul24.wav
# stop 1 00088_jul24.wav
# stop 1 00478_jul24.wav
# stop 1 00621_jul24.wav
# stop 1 00554_jul24.wav
# stop 1 00156_jul24.wav
# stop 1 00557_jul20.wav
# stop 1 00488_jul24.wav
# stop 1 00176_jul20.wav
# stop 1 00185_jul20.wav
# stop 1 00033_jul24.wav
# stop 1 00051_jul23.wav
# stop 1 00095_jul09.wav
# stop 1 00408_jul20.wav
# stop 1 00254_jul20.wav
# stop 1 00145_jul23.wav
# stop 1 00272_jul20.wav
# stop 1 00280_jul23.wav
# stop 1 00006_jul23.wav
# stop 1 00164_jul24.wav
# stop 1 00152_jul09.wav
# stop 1 00568_jul20.wav
# stop 1 00582_jul20.wav
# stop 1 00361_jul24.wav
# stop 1 00380_jul20.wav
# stop 1 00263_jul20.wav
# stop 1 00521_jul23.wav
# stop 1 00039_jul23.wav
# stop 1 00176_jul09.wav
# stop 1 00022_jul24.wav
# stop 1 00091_jul20.wav
# stop 1 00417_jul23.wav
# stop 1 00128_jul09.wav
# stop 1 00326_jul23.wav
# stop 1 00329_jul20.wav
# stop 1 00449_jul23.wav
# stop 1 00536_jul23.wav
# stop 1 00588_jul24.wav
# stop 1 00253_jul24.wav
# stop 1 00601_jul24.wav
# stop 1 00209_jul24.wav
# stop 1 00025_jul24.wav
# stop 1 00608_jul24.wav
# stop 1 00232_jul24.wav
# stop 1 00036_jul23.wav
# stop 1 00018_jul09.wav
# stop 1 00610_jul24.wav
# stop 1 00177_jul09.wav
# stop 1 00490_jul24.wav
# stop 1 00307_jul23.wav
# stop 1 00235_jul20.wav
# stop 1 00007_jul24.wav
# stop 1 00114_jul09.wav
# stop 1 00138_jul09.wav
# stop 1 00505_jul20.wav
# stop 1 00229_jul23.wav
# stop 1 00078_jul20.wav
# stop 1 00383_jul23.wav
# stop 1 00054_jul24.wav
# stop 1 00515_jul24.wav
# stop 1 00353_jul20.wav
# stop 1 00006_jul20.wav
# stop 1 00137_jul09.wav
# stop 1 00244_jul20.wav
# stop 1 00292_jul23.wav
# stop 1 00287_jul20.wav
# stop 1 00294_jul20.wav
# stop 1 00403_jul24.wav
# stop 1 00372_jul23.wav
# stop 1 00013_jul24.wav
# stop 1 00346_jul23.wav
# stop 1 00240_jul23.wav
# stop 1 00104_jul23.wav
# stop 1 00049_jul20.wav
# stop 1 00036_jul09.wav
# stop 1 00378_jul24.wav
# stop 1 00182_jul23.wav
# stop 1 00041_jul20.wav
# stop 1 00144_jul23.wav
# stop 1 00461_jul23.wav
# stop 1 00246_jul23.wav
# stop 1 00544_jul20.wav
# stop 1 00443_jul24.wav
# stop 1 00424_jul23.wav
# stop 1 00341_jul20.wav
# stop 1 00007_jul23.wav
# stop 1 00212_jul24.wav
# stop 1 00301_jul23.wav
# stop 1 00151_jul23.wav
# ...
# stop 1 00171_jul09.wav
# stop 1 00361_jul23.wav
# stop 1 00158_jul20.wav
# stop 1 00485_jul23.wav
# stop 1 00263_jul23.wav
# stop 1 00184_jul24.wav
# stop 1 00538_jul20.wav
# stop 1 00477_jul20.wav
# stop 1 00139_jul09.wav
# stop 1 00031_jul20.wav
# stop 1 00330_jul23.wav
# stop 1 00185_jul23.wav
# stop 1 00075_jul20.wav
# stop 1 00188_jul24.wav
# stop 1 00341_jul23.wav
# stop 1 00551_jul23.wav
# stop 1 00533_jul23.wav
# stop 1 00351_jul20.wav
# stop 1 00394_jul20.wav
# stop 1 00343_jul23.wav
# stop 1 00143_jul23.wav
# stop 1 00003_jul09.wav
# stop 1 00315_jul20.wav
# stop 1 00186_jul23.wav
# stop 1 00192_jul24.wav
# stop 1 00215_jul24.wav
# stop 1 00276_jul24.wav
# stop 1 00269_jul24.wav
# stop 1 00516_jul23.wav
# stop 1 00331_jul23.wav
# stop 1 00399_jul24.wav
# stop 1 00192_jul20.wav
# stop 1 00002_jul24.wav
# stop 1 00338_jul20.wav
# stop 1 00497_jul20.wav
# stop 1 00479_jul23.wav
# stop 1 00014_jul09.wav
# stop 1 00521_jul24.wav
# stop 1 00071_jul09.wav
# stop 1 00346_jul24.wav
# stop 1 00040_jul24.wav
# stop 1 00588_jul20.wav
# stop 1 00374_jul23.wav
# stop 1 00097_jul23.wav
# stop 1 00073_jul24.wav
# stop 1 00115_jul23.wav
# stop 1 00179_jul09.wav
# stop 1 00189_jul24.wav
# stop 1 00494_jul24.wav
# stop 1 00095_jul23.wav
# stop 1 00129_jul09.wav
# stop 1 00187_jul20.wav
# stop 1 00112_jul23.wav
# stop 1 00029_jul20.wav
# stop 1 00439_jul24.wav
# stop 1 00210_jul24.wav
# stop 1 00458_jul20.wav
# stop 1 00221_jul20.wav
# stop 1 00560_jul24.wav
# stop 1 00144_jul20.wav
# stop 1 00185_jul09.wav
# stop 1 00324_jul24.wav
# stop 1 00131_jul23.wav
# stop 1 00514_jul24.wav
# stop 1 00164_jul20.wav
# stop 1 00137_jul23.wav
# stop 1 00126_jul20.wav
# stop 1 00390_jul24.wav
# stop 1 00311_jul24.wav
# stop 1 00231_jul23.wav
# stop 1 00242_jul24.wav
# stop 1 00103_jul20.wav
# stop 1 00133_jul23.wav
# stop 1 00540_jul23.wav
# stop 1 00182_jul09.wav
# stop 1 00444_jul24.wav
# stop 1 00309_jul24.wav
# stop 1 00290_jul23.wav
# stop 1 00165_jul23.wav
# stop 1 00102_jul09.wav
# stop 1 00031_jul23.wav
# stop 1 00175_jul24.wav
# stop 1 00194_jul24.wav
# stop 1 00200_jul23.wav
# stop 1 00007_jul20.wav
# stop 1 00332_jul20.wav
# stop 1 00206_jul24.wav
# stop 1 00288_jul23.wav
# stop 1 00531_jul20.wav
# stop 1 00454_jul24.wav
# stop 1 00100_jul09.wav
# stop 1 00510_jul20.wav
# stop 1 00175_jul20.wav
# stop 1 00228_jul23.wav
# stop 1 00364_jul20.wav
# stop 1 00198_jul23.wav
# stop 1 00126_jul23.wav
# stop 1 00327_jul23.wav
# stop 1 00362_jul20.wav
# stop 1 00575_jul24.wav
# stop 1 00132_jul23.wav
# stop 1 00236_jul20.wav
# stop 1 00342_jul23.wav
# stop 1 00571_jul23.wav
# stop 1 00307_jul24.wav
# stop 1 00239_jul23.wav
# stop 1 00590_jul24.wav
# stop 1 00050_jul20.wav
# stop 1 00148_jul20.wav
# stop 1 00095_jul20.wav
# stop 1 00334_jul20.wav
# stop 1 00391_jul23.wav
# stop 1 00596_jul24.wav
# stop 1 00032_jul23.wav
# stop 1 00162_jul09.wav
# stop 1 00515_jul20.wav
# stop 1 00498_jul23.wav
# stop 1 00043_jul23.wav
# stop 1 00506_jul24.wav
# stop 1 00248_jul24.wav
# stop 1 00230_jul24.wav
# stop 1 00525_jul23.wav
# stop 1 00576_jul20.wav
# stop 1 00172_jul20.wav
# stop 1 00342_jul24.wav
# stop 1 00526_jul23.wav
# stop 1 00364_jul23.wav
# stop 1 00207_jul24.wav
# stop 1 00452_jul24.wav
# stop 1 00570_jul20.wav
# stop 1 00127_jul20.wav
# stop 1 00586_jul20.wav
# stop 1 00593_jul24.wav
# stop 1 00150_jul24.wav
# stop 1 00572_jul20.wav
# stop 1 00035_jul23.wav
# stop 1 00298_jul20.wav
# stop 1 00159_jul09.wav
# stop 1 00577_jul24.wav
# stop 1 00043_jul20.wav
# stop 1 00067_jul20.wav
# stop 1 00057_jul23.wav
# stop 1 00275_jul20.wav
# stop 1 00068_jul23.wav
# stop 1 00062_jul24.wav
# stop 1 00246_jul24.wav
# stop 1 00475_jul20.wav
# stop 1 00464_jul20.wav
# stop 1 00107_jul23.wav
# stop 1 00170_jul09.wav
# stop 1 00199_jul24.wav
# stop 1 00250_jul20.wav
# stop 1 00035_jul20.wav
# stop 1 00048_jul20.wav
# stop 1 00359_jul20.wav
# stop 1 00315_jul23.wav
# stop 1 00467_jul23.wav
# stop 1 00254_jul24.wav
# stop 1 00066_jul24.wav
# stop 1 00063_jul24.wav
# stop 1 00524_jul23.wav
# stop 1 00459_jul20.wav
# stop 1 00389_jul23.wav
# stop 1 00086_jul20.wav
# stop 1 00367_jul24.wav
# stop 1 00535_jul24.wav
# stop 1 00206_jul20.wav
# stop 1 00024_jul23.wav
# stop 1 00178_jul23.wav
# stop 1 00571_jul24.wav
# stop 1 00337_jul23.wav
# stop 1 00109_jul23.wav
# stop 1 00282_jul23.wav
# stop 1 00560_jul20.wav
# stop 1 00121_jul23.wav
# stop 1 00268_jul24.wav
# stop 1 00410_jul20.wav
# stop 1 00487_jul23.wav
# stop 1 00309_jul23.wav
# stop 1 00146_jul20.wav
# stop 1 00211_jul23.wav
# stop 1 00112_jul24.wav
# stop 1 00552_jul23.wav
# stop 1 00545_jul20.wav
# stop 1 00200_jul20.wav
# stop 1 00399_jul20.wav
# stop 1 00563_jul23.wav
# stop 1 00090_jul09.wav
# stop 1 00172_jul24.wav
# stop 1 00167_jul23.wav
# stop 1 00420_jul20.wav
# stop 1 00027_jul23.wav
# stop 1 00045_jul20.wav
# stop 1 00155_jul23.wav
# stop 1 00578_jul20.wav
# stop 1 00251_jul23.wav
# stop 1 00087_jul24.wav
# stop 1 00519_jul23.wav
# stop 1 00396_jul24.wav
# stop 1 00159_jul23.wav
# stop 1 00484_jul20.wav
# stop 1 00305_jul24.wav
# stop 1 00207_jul20.wav
# stop 1 00133_jul20.wav
# stop 1 00150_jul23.wav
# stop 1 00258_jul20.wav
# stop 1 00132_jul24.wav
# stop 1 00374_jul20.wav
# stop 1 00062_jul09.wav
# stop 1 00022_jul09.wav
# stop 1 00504_jul20.wav
# stop 1 00496_jul20.wav
# stop 1 00515_jul23.wav
# stop 1 00500_jul20.wav
# stop 1 00047_jul20.wav
# stop 1 00322_jul20.wav
# stop 1 00441_jul23.wav
# stop 1 00146_jul09.wav
# stop 1 00319_jul20.wav
# stop 1 00054_jul20.wav
# stop 1 00180_jul24.wav
# stop 1 00011_jul09.wav
# stop 1 00019_jul24.wav
# stop 1 00383_jul20.wav
# stop 1 00624_jul24.wav
# stop 1 00186_jul20.wav
# stop 1 00050_jul24.wav
# stop 1 00154_jul24.wav
# stop 1 00002_jul23.wav
# stop 1 00233_jul20.wav
# stop 1 00450_jul23.wav
# stop 1 00539_jul20.wav
# stop 1 00477_jul23.wav
# stop 1 00559_jul20.wav
# stop 1 00388_jul24.wav
# stop 1 00110_jul24.wav
# stop 1 00401_jul23.wav
# stop 1 00499_jul24.wav
# stop 1 00507_jul24.wav
# stop 1 00349_jul24.wav
# stop 1 00126_jul09.wav
# stop 1 00607_jul24.wav
# stop 1 00106_jul23.wav
# stop 1 00076_jul24.wav
# stop 1 00222_jul20.wav
# stop 1 00555_jul24.wav
# stop 1 00005_jul09.wav
# stop 1 00111_jul09.wav
# stop 1 00067_jul09.wav
# stop 1 00549_jul24.wav
# stop 1 00450_jul24.wav
# stop 1 00358_jul23.wav
# stop 1 00045_jul24.wav
# stop 1 00430_jul20.wav
# stop 1 00333_jul20.wav
# stop 1 00124_jul23.wav
# stop 1 00300_jul24.wav
# stop 1 00065_jul23.wav
# stop 1 00331_jul20.wav
# stop 1 00251_jul24.wav
# stop 1 00474_jul20.wav
# stop 1 00472_jul23.wav
# stop 1 00492_jul23.wav
# stop 1 00498_jul20.wav
# stop 1 00365_jul20.wav
# stop 1 00457_jul23.wav
# stop 1 00486_jul23.wav
# stop 1 00584_jul24.wav
# stop 1 00563_jul24.wav
# stop 1 00567_jul20.wav
# stop 1 00077_jul23.wav
# stop 1 00304_jul20.wav
# stop 1 00323_jul23.wav
# stop 1 00122_jul20.wav
# stop 1 00623_jul24.wav
# stop 1 00313_jul20.wav
# stop 1 00345_jul20.wav
# stop 1 00311_jul23.wav
# stop 1 00081_jul09.wav
# stop 1 00461_jul20.wav
# stop 1 00463_jul20.wav
# stop 1 00193_jul20.wav
# stop 1 00217_jul24.wav
# stop 1 00140_jul20.wav
# stop 1 00527_jul24.wav
# stop 1 00018_jul20.wav
# stop 1 00140_jul09.wav
# stop 1 00516_jul24.wav
# stop 1 00230_jul23.wav
# stop 1 00178_jul20.wav
# stop 1 00440_jul20.wav
# stop 1 00046_jul20.wav
# stop 1 00027_jul09.wav
# stop 1 00219_jul23.wav
# stop 1 00487_jul24.wav
# stop 1 00070_jul20.wav
# stop 1 00000_jul20.wav
# stop 1 00434_jul24.wav
# stop 1 00063_jul23.wav
# stop 1 00182_jul20.wav
# stop 1 00394_jul23.wav
# stop 1 00292_jul24.wav
# stop 1 00332_jul23.wav
# stop 1 00425_jul23.wav
# stop 1 00115_jul24.wav
# stop 1 00163_jul23.wav
# stop 1 00349_jul20.wav
# stop 1 00070_jul23.wav
# stop 1 00048_jul23.wav
# stop 1 00220_jul20.wav
# stop 1 00237_jul24.wav
# stop 1 00169_jul24.wav
# stop 1 00572_jul24.wav
# stop 1 00324_jul23.wav
# stop 1 00465_jul24.wav
# stop 1 00384_jul23.wav
# stop 1 00174_jul20.wav
# stop 1 00549_jul23.wav
# stop 1 00243_jul24.wav
# stop 1 00158_jul09.wav
# stop 1 00193_jul24.wav
# stop 1 00217_jul23.wav
# stop 1 00119_jul20.wav
# stop 1 00334_jul23.wav
# stop 1 00038_jul09.wav
# stop 1 00595_jul24.wav
# stop 1 00318_jul24.wav
# stop 1 00467_jul20.wav
# stop 1 00312_jul24.wav
# stop 1 00255_jul23.wav
# stop 1 00467_jul24.wav
# stop 1 00519_jul20.wav
# stop 1 00584_jul20.wav
# stop 1 00064_jul09.wav
# stop 1 00419_jul24.wav
# stop 1 00483_jul23.wav
# stop 1 00505_jul24.wav
# stop 1 00123_jul24.wav
# stop 1 00434_jul20.wav
# stop 1 00093_jul20.wav
# stop 1 00116_jul20.wav
# stop 1 00306_jul20.wav
# stop 1 00519_jul24.wav
# stop 1 00455_jul24.wav
# stop 1 00361_jul20.wav
# stop 1 00619_jul24.wav
# stop 1 00348_jul24.wav
# stop 1 00493_jul20.wav
# stop 1 00489_jul23.wav
# stop 1 00083_jul09.wav
# stop 1 00400_jul20.wav
# stop 1 00573_jul23.wav
# stop 1 00561_jul23.wav
# stop 1 00476_jul23.wav
# stop 1 00234_jul23.wav
# stop 1 00307_jul20.wav
# stop 1 00452_jul23.wav
# stop 1 00565_jul24.wav
# stop 1 00567_jul23.wav
# stop 1 00347_jul24.wav
# stop 1 00040_jul23.wav
# stop 1 00247_jul20.wav
# stop 1 00187_jul09.wav
# stop 1 00483_jul24.wav
# stop 1 00508_jul24.wav
# stop 1 00041_jul09.wav
# stop 1 00022_jul23.wav
# stop 1 00063_jul20.wav
# stop 1 00592_jul24.wav
# stop 1 00427_jul20.wav
# stop 1 00417_jul20.wav
# stop 1 00492_jul20.wav
# stop 1 00579_jul24.wav
# stop 1 00422_jul23.wav
# stop 1 00026_jul09.wav
# stop 1 00487_jul20.wav
# stop 1 00373_jul20.wav
# stop 1 00291_jul20.wav
# stop 1 00560_jul23.wav
# stop 1 00160_jul20.wav
# stop 1 00476_jul24.wav
# stop 1 00136_jul24.wav
# stop 1 00222_jul24.wav
# stop 1 00259_jul24.wav
# stop 1 00165_jul20.wav
# stop 1 00399_jul23.wav
# stop 1 00594_jul24.wav
# stop 1 00259_jul20.wav
# stop 1 00195_jul20.wav
# stop 1 00401_jul20.wav
# stop 1 00333_jul23.wav
# stop 1 00522_jul24.wav
# stop 1 00011_jul24.wav
# stop 1 00029_jul23.wav
# stop 1 00285_jul24.wav
# stop 1 00426_jul20.wav
# stop 1 00218_jul23.wav
# stop 1 00589_jul24.wav
# stop 1 00312_jul23.wav
# stop 1 00426_jul23.wav
# stop 1 00252_jul23.wav
# stop 1 00281_jul20.wav
# stop 1 00129_jul24.wav
# stop 1 00035_jul24.wav
# stop 1 00132_jul20.wav
# stop 1 00083_jul20.wav
# stop 1 00286_jul24.wav
# stop 1 00571_jul20.wav
# stop 1 00316_jul24.wav
# stop 1 00231_jul20.wav
# stop 1 00586_jul24.wav
# stop 1 00058_jul20.wav
# stop 1 00384_jul20.wav
# stop 1 00356_jul23.wav
# stop 1 00336_jul20.wav
# stop 1 00577_jul20.wav
# stop 1 00273_jul20.wav
# stop 1 00080_jul24.wav
# stop 1 00377_jul23.wav
# stop 1 00224_jul24.wav
# stop 1 00413_jul24.wav
# stop 1 00326_jul20.wav
# stop 1 00028_jul24.wav
# stop 1 00023_jul24.wav
# stop 1 00542_jul20.wav
# stop 1 00499_jul23.wav
# stop 1 00318_jul20.wav
# stop 1 00261_jul20.wav
# stop 1 00362_jul24.wav
# stop 1 00284_jul23.wav
# stop 1 00149_jul23.wav
# stop 1 00192_jul23.wav
# stop 1 00281_jul24.wav
# stop 1 00390_jul23.wav
# stop 1 00055_jul09.wav
# stop 1 00350_jul24.wav
# stop 1 00359_jul23.wav
# stop 1 00090_jul23.wav
# stop 1 00042_jul23.wav
# stop 1 00144_jul24.wav
# stop 1 00523_jul23.wav
# stop 1 00109_jul24.wav
# stop 1 00173_jul23.wav
# stop 1 00004_jul09.wav
# stop 1 00057_jul09.wav
# stop 1 00244_jul24.wav
# stop 1 00260_jul24.wav
# stop 1 00569_jul24.wav
# stop 1 00616_jul24.wav
# stop 1 00071_jul24.wav
# stop 1 00368_jul24.wav
# stop 1 00019_jul20.wav
# stop 1 00128_jul20.wav
# stop 1 00233_jul23.wav
# stop 1 00413_jul23.wav
# stop 1 00475_jul24.wav
# stop 1 00154_jul20.wav
# stop 1 00242_jul23.wav
# stop 1 00354_jul23.wav
# stop 1 00279_jul23.wav
# stop 1 00322_jul24.wav
# stop 1 00046_jul09.wav
# stop 1 00594_jul20.wav
# stop 1 00248_jul23.wav
# stop 1 00065_jul20.wav
# stop 1 00295_jul20.wav
# stop 1 00426_jul24.wav
# stop 1 00236_jul23.wav
# stop 1 00297_jul23.wav
# stop 1 00010_jul23.wav
# stop 1 00142_jul09.wav
# stop 1 00349_jul23.wav
# stop 1 00170_jul24.wav
# stop 1 00425_jul24.wav
# stop 1 00497_jul23.wav
# stop 1 00324_jul20.wav
# stop 1 00114_jul24.wav
# stop 1 00475_jul23.wav
# stop 1 00513_jul24.wav
# stop 1 00539_jul23.wav
# stop 1 00059_jul09.wav
# stop 1 00437_jul20.wav
# stop 1 00255_jul24.wav
# stop 1 00418_jul24.wav
# stop 1 00121_jul20.wav
# stop 1 00249_jul23.wav
# stop 1 00027_jul24.wav
# stop 1 00509_jul24.wav
# stop 1 00463_jul24.wav
# stop 1 00524_jul20.wav
# stop 1 00438_jul23.wav
# stop 1 00141_jul09.wav
# stop 1 00463_jul23.wav
# stop 1 00532_jul24.wav
# stop 1 00270_jul20.wav
# stop 1 00282_jul20.wav
# stop 1 00196_jul23.wav
# stop 1 00544_jul24.wav
# stop 1 00247_jul23.wav
# stop 1 00488_jul23.wav
# stop 1 00416_jul20.wav
# stop 1 00275_jul24.wav
# stop 1 00051_jul24.wav
# stop 1 00306_jul24.wav
# stop 1 00301_jul20.wav
# stop 1 00453_jul24.wav
# stop 1 00068_jul20.wav
# stop 1 00120_jul09.wav
# stop 1 00153_jul24.wav
# stop 1 00258_jul24.wav
# stop 1 00052_jul20.wav
# stop 1 00495_jul23.wav
# stop 1 00419_jul20.wav
# stop 1 00482_jul23.wav
# stop 1 00131_jul24.wav
# stop 1 00012_jul20.wav
# stop 1 00026_jul24.wav
# stop 1 00292_jul20.wav
# stop 1 00521_jul20.wav
# stop 1 00220_jul24.wav
# stop 1 00340_jul20.wav
# stop 1 00269_jul20.wav
# stop 1 00030_jul09.wav
# stop 1 00315_jul24.wav
# stop 1 00171_jul23.wav
# stop 1 00234_jul20.wav
# stop 1 00469_jul24.wav
# stop 1 00016_jul09.wav
# stop 1 00365_jul24.wav
# stop 1 00280_jul24.wav
# stop 1 00322_jul23.wav
# stop 1 00347_jul20.wav
# stop 1 00107_jul24.wav
# stop 1 00313_jul23.wav
# stop 1 00388_jul20.wav
# stop 1 00082_jul23.wav
# stop 1 00348_jul23.wav
# stop 1 00118_jul09.wav
# stop 1 00094_jul23.wav
# stop 1 00395_jul23.wav
# stop 1 00088_jul20.wav
# stop 1 00547_jul23.wav
# stop 1 00573_jul24.wav
# stop 1 00339_jul23.wav
# stop 1 00580_jul20.wav
# stop 1 00050_jul09.wav
# stop 1 00053_jul20.wav
# stop 1 00273_jul24.wav
# stop 1 00446_jul24.wav
# stop 1 00038_jul24.wav
# stop 1 00194_jul20.wav
# stop 1 00423_jul24.wav
# stop 1 00109_jul09.wav
# stop 1 00056_jul23.wav
# stop 1 00383_jul24.wav
# stop 1 00221_jul23.wav
# stop 1 00025_jul20.wav
# stop 1 00155_jul20.wav
# stop 1 00010_jul24.wav
# stop 1 00134_jul23.wav
# stop 1 00212_jul23.wav
# stop 1 00328_jul23.wav
# stop 1 00019_jul23.wav
# stop 1 00362_jul23.wav
# stop 1 00181_jul24.wav
# stop 1 00567_jul24.wav
# stop 1 00120_jul24.wav
# stop 1 00303_jul20.wav
# stop 1 00028_jul23.wav
# stop 1 00134_jul09.wav
# stop 1 00528_jul23.wav
# stop 1 00042_jul24.wav
# stop 1 00171_jul20.wav
# stop 1 00123_jul09.wav
# stop 1 00279_jul20.wav
# stop 1 00474_jul24.wav
# stop 1 00436_jul23.wav
# stop 1 00500_jul24.wav
# stop 1 00353_jul24.wav
# stop 1 00090_jul20.wav
# stop 1 00394_jul24.wav
# stop 1 00229_jul24.wav
# stop 1 00423_jul23.wav
# stop 1 00531_jul24.wav
# stop 1 00385_jul20.wav
# stop 1 00061_jul23.wav
# stop 1 00343_jul20.wav
# stop 1 00320_jul23.wav
# stop 1 00368_jul23.wav
# stop 1 00438_jul24.wav
# stop 1 00376_jul20.wav
# stop 1 00073_jul20.wav
# stop 1 00568_jul23.wav
# stop 1 00260_jul20.wav
# stop 1 00183_jul23.wav
# stop 1 00164_jul23.wav
# stop 1 00277_jul20.wav
# stop 1 00224_jul20.wav
# stop 1 00405_jul24.wav
# stop 1 00583_jul24.wav
# stop 1 00017_jul20.wav
# stop 1 00552_jul20.wav
# stop 1 00339_jul24.wav
# stop 1 00284_jul24.wav
# stop 1 00163_jul20.wav
# stop 1 00227_jul23.wav
# stop 1 00268_jul20.wav
# stop 1 00001_jul09.wav
# stop 1 00375_jul23.wav
# stop 1 00196_jul20.wav
# stop 1 00062_jul20.wav
# stop 1 00431_jul24.wav
# stop 1 00142_jul20.wav
# stop 1 00378_jul20.wav
# stop 1 00003_jul23.wav
# stop 1 00294_jul24.wav
# stop 1 00446_jul20.wav
# stop 1 00049_jul09.wav
# stop 1 00092_jul23.wav
# stop 1 00587_jul24.wav
# stop 1 00417_jul24.wav
# stop 1 00069_jul09.wav
# stop 1 00030_jul20.wav
# stop 1 00189_jul23.wav
# stop 1 00225_jul23.wav
# stop 1 00271_jul20.wav
# stop 1 00148_jul23.wav
# stop 1 00438_jul20.wav
# stop 1 00160_jul23.wav
# stop 1 00431_jul20.wav
# stop 1 00024_jul20.wav
# stop 1 00536_jul24.wav
# stop 1 00573_jul20.wav
# stop 1 00581_jul24.wav
# stop 1 00244_jul23.wav
# stop 1 00100_jul20.wav
# stop 1 00267_jul20.wav
# stop 1 00374_jul24.wav
# stop 1 00620_jul24.wav
# stop 1 00541_jul20.wav
# stop 1 00087_jul20.wav
# stop 1 00051_jul09.wav
# stop 1 00336_jul23.wav
# stop 1 00550_jul24.wav
# stop 1 00484_jul24.wav
# stop 1 00141_jul23.wav
# stop 1 00451_jul20.wav
# stop 1 00023_jul20.wav
# stop 1 00161_jul23.wav
# stop 1 00473_jul24.wav
# stop 1 00382_jul20.wav
# stop 1 00146_jul23.wav
# stop 1 00229_jul20.wav
# stop 1 00537_jul20.wav
# stop 1 00069_jul24.wav
# stop 1 00181_jul09.wav
# stop 1 00084_jul09.wav
# stop 1 00211_jul20.wav
# stop 1 00269_jul23.wav
# stop 1 00405_jul20.wav
# stop 1 00162_jul20.wav
# stop 1 00480_jul20.wav
# stop 1 00143_jul09.wav
# stop 1 00599_jul24.wav
# stop 1 00080_jul23.wav
# stop 1 00409_jul24.wav
# stop 1 00041_jul24.wav
# stop 1 00215_jul23.wav
# stop 1 00070_jul24.wav
# stop 1 00237_jul20.wav
# stop 1 00232_jul20.wav
# stop 1 00552_jul24.wav
# stop 1 00101_jul20.wav
# stop 1 00246_jul20.wav
# stop 1 00482_jul24.wav
# stop 1 00291_jul24.wav
# stop 1 00150_jul20.wav
# stop 1 00154_jul09.wav
# stop 1 00433_jul23.wav
# stop 1 00184_jul23.wav
# stop 1 00549_jul20.wav
# stop 1 00161_jul24.wav
# stop 1 00325_jul20.wav
# stop 1 00344_jul23.wav
# stop 1 00007_jul09.wav
# stop 1 00037_jul23.wav
# stop 1 00502_jul24.wav
# stop 1 00264_jul23.wav
# stop 1 00211_jul24.wav
# stop 1 00508_jul20.wav
# stop 1 00558_jul24.wav
# stop 1 00298_jul24.wav
# stop 1 00082_jul24.wav
# stop 1 00048_jul09.wav
# stop 1 00224_jul23.wav

# %%
# for i, x in enumerate(subFolderList):
#     if x in labels_to_keep:
#         print(i, ':', x)
#         # get all the wave files
#         all_files = [y for y in os.listdir(audio_path + x) if '.wav' in y]
#         for file in all_files[101:120]:
#             wav2img(audio_path + x + '/' + file, test_pict_Path + x)
#     else:
#         all_files = [y for y in os.listdir(audio_path + x) if '.wav' in y]
#         for file in all_files[16:20]:
#             wav2img(audio_path + x + '/' + file, "./input/picts/test/unknown")

# %%
# test = tf.image.decode_png("./input/picts/train/down/00b01445_nohash_1.png",3)
# sess = tf.Session()
# print(sess.run(test))

# %%
train_images = []
train_labels = []
for i, x in enumerate(['yes','no', 'stop']): #choose the classes to train
    all_files = [y for y in os.listdir(pic_path + x + "/ch1") if '.jpg' in y]
    for file in all_files:
        train_images.append(cv2.imread(pic_path + x + '/ch1/' + file))
        train_labels.append(label_dict[x])

train_images = np.array(train_images, dtype="float32")
train_images /= 255
train_labels = np.array(train_labels)
print(train_images.shape)
print(type(train_labels))
# Out:
# (5825, 96, 96, 3)
# <class 'numpy.ndarray'>

# %%
print(train_labels.shape)
# Out:
# (5825,)

# %%
# code to shuffe feature and label arrays.
#train_labels.reshape((1, -1))
train_labels = np.array(train_labels, dtype="int32")
randomize = np.arange(len(train_labels))
np.random.shuffle(randomize)
print(train_labels)
labels = train_labels[randomize]
features = train_images[randomize]
print(labels)
# Out:
# [0 0 0 ..., 2 2 2]
# [1 0 1 ..., 0 0 0]

# %%
print(len(labels))
# Out:
# 5825

# %%
# code to split training and validation data
x = len(labels)
x *= 0.8
x = int(x)
training_examples = features[:x]
validation_examples = features[x:]

training_targets = labels[:x]
validation_targets = labels[x:]
print(training_targets)
print(validation_targets)
print(training_targets.shape)
print(validation_targets.shape)
print(training_examples)
# Out:
# [1 0 1 ..., 1 2 0]
# [0 2 1 ..., 0 0 0]
# (4660,)
# (1165,)
# [[[[ 0.41176471  0.41176471  0.41176471]
#    [ 0.41176471  0.41176471  0.41176471]
#    [ 0.41176471  0.41176471  0.41176471]
#    ...,
#    [ 0.49019608  0.49019608  0.49019608]
#    [ 0.49019608  0.49019608  0.49019608]
#    [ 0.49019608  0.49019608  0.49019608]]
#
#   [[ 0.42745098  0.42745098  0.42745098]
#    [ 0.42745098  0.42745098  0.42745098]
#    [ 0.42745098  0.42745098  0.42745098]
#    ...,
#    [ 0.52549022  0.52549022  0.52549022]
#    [ 0.52549022  0.52549022  0.52549022]
#    [ 0.52549022  0.52549022  0.52549022]]
#
#   [[ 0.38431373  0.38431373  0.38431373]
#    [ 0.38431373  0.38431373  0.38431373]
#    [ 0.38431373  0.38431373  0.38431373]
#    ...,
#    [ 0.48627451  0.48627451  0.48627451]
#    [ 0.48627451  0.48627451  0.48627451]
#    [ 0.48627451  0.48627451  0.48627451]]
#
#   ...,
#   [[ 0.6901961   0.6901961   0.6901961 ]
#    [ 0.6901961   0.6901961   0.6901961 ]
#    [ 0.6901961   0.6901961   0.6901961 ]
#    ...,
#    [ 0.72156864  0.72156864  0.72156864]
#    [ 0.72156864  0.72156864  0.72156864]
#    [ 0.72156864  0.72156864  0.72156864]]
#
#   [[ 0.7764706   0.7764706   0.7764706 ]
#    [ 0.7764706   0.7764706   0.7764706 ]
#    [ 0.7764706   0.7764706   0.7764706 ]
#    ...,
#    [ 0.86666667  0.86666667  0.86666667]
#    [ 0.86666667  0.86666667  0.86666667]
#    [ 0.86666667  0.86666667  0.86666667]]
#
#   [[ 0.72156864  0.72156864  0.72156864]
#    [ 0.72156864  0.72156864  0.72156864]
#    [ 0.72156864  0.72156864  0.72156864]
#    ...,
#    [ 1.          1.          1.        ]
#    [ 1.          1.          1.        ]
#    [ 1.          1.          1.        ]]]
#
#
#  [[[ 0.51372552  0.51372552  0.51372552]
#    [ 0.51372552  0.51372552  0.51372552]
#    [ 0.5411765   0.5411765   0.5411765 ]
#    ...,
#    [ 0.49803922  0.49803922  0.49803922]
#    [ 0.47058824  0.47058824  0.47058824]
#    [ 0.47058824  0.47058824  0.47058824]]
#
#   [[ 0.44313726  0.44313726  0.44313726]
#    [ 0.44313726  0.44313726  0.44313726]
#    [ 0.46666667  0.46666667  0.46666667]
#    ...,
#    [ 0.43137255  0.43137255  0.43137255]
#    [ 0.40000001  0.40000001  0.40000001]
#    [ 0.40000001  0.40000001  0.40000001]]
#
#   [[ 0.41568628  0.41568628  0.41568628]
#    [ 0.41568628  0.41568628  0.41568628]
#    [ 0.44313726  0.44313726  0.44313726]
#    ...,
#    [ 0.40000001  0.40000001  0.40000001]
#    [ 0.3764706   0.3764706   0.3764706 ]
#    [ 0.3764706   0.3764706   0.3764706 ]]
#
#   ...,
#   [[ 0.91764706  0.91764706  0.91764706]
#    [ 0.91764706  0.91764706  0.91764706]
#    [ 0.92941177  0.92941177  0.92941177]
#    ...,
#    [ 0.94117647  0.94117647  0.94117647]
#    [ 0.95686275  0.95686275  0.95686275]
#    [ 0.95686275  0.95686275  0.95686275]]
#
#   [[ 0.84313726  0.84313726  0.84313726]
#    [ 0.84313726  0.84313726  0.84313726]
#    [ 0.85490197  0.85490197  0.85490197]
#    ...,
#    [ 0.95686275  0.95686275  0.95686275]
#    [ 0.97254902  0.97254902  0.97254902]
#    [ 0.97254902  0.97254902  0.97254902]]
#
#   [[ 0.78431374  0.78431374  0.78431374]
#    [ 0.78431374  0.78431374  0.78431374]
#    [ 0.78431374  0.78431374  0.78431374]
#    ...,
#    [ 0.88627452  0.88627452  0.88627452]
#    [ 0.86666667  0.86666667  0.86666667]
#    [ 0.86666667  0.86666667  0.86666667]]]
#
#
#  [[[ 0.36470589  0.36470589  0.36470589]
#    [ 0.36470589  0.36470589  0.36470589]
#    [ 0.39215687  0.39215687  0.39215687]
#    ...,
#    [ 0.3882353   0.3882353   0.3882353 ]
#    [ 0.36470589  0.36470589  0.36470589]
#    [ 0.36470589  0.36470589  0.36470589]]
#
#   [[ 0.28627452  0.28627452  0.28627452]
#    [ 0.28627452  0.28627452  0.28627452]
#    [ 0.32549021  0.32549021  0.32549021]
#    ...,
#    [ 0.32549021  0.32549021  0.32549021]
#    [ 0.28627452  0.28627452  0.28627452]
#    [ 0.28627452  0.28627452  0.28627452]]
#
#   [[ 0.24313726  0.24313726  0.24313726]
#    [ 0.24313726  0.24313726  0.24313726]
#    [ 0.28627452  0.28627452  0.28627452]
#    ...,
#    [ 0.29411766  0.29411766  0.29411766]
#    [ 0.25098041  0.25098041  0.25098041]
#    [ 0.25098041  0.25098041  0.25098041]]
#
#   ...,
#   [[ 0.81176472  0.81176472  0.81176472]
#    [ 0.81176472  0.81176472  0.81176472]
#    [ 0.84313726  0.84313726  0.84313726]
#    ...,
#    [ 0.77254903  0.77254903  0.77254903]
#    [ 0.75294119  0.75294119  0.75294119]
#    [ 0.75294119  0.75294119  0.75294119]]
#
#   [[ 0.7647059   0.7647059   0.7647059 ]
#    [ 0.7647059   0.7647059   0.7647059 ]
#    [ 0.78431374  0.78431374  0.78431374]
#    ...,
#    [ 0.70980394  0.70980394  0.70980394]
#    [ 0.68627453  0.68627453  0.68627453]
#    [ 0.68627453  0.68627453  0.68627453]]
#
#   [[ 0.72156864  0.72156864  0.72156864]
#    [ 0.72156864  0.72156864  0.72156864]
#    [ 0.74509805  0.74509805  0.74509805]
#    ...,
#    [ 0.66666669  0.66666669  0.66666669]
#    [ 0.64313728  0.64313728  0.64313728]
#    [ 0.64313728  0.64313728  0.64313728]]]
#
#
#  ...,
#  [[[ 0.35686275  0.35686275  0.35686275]
#    [ 0.35686275  0.35686275  0.35686275]
#    [ 0.38431373  0.38431373  0.38431373]
#    ...,
#    [ 0.42352942  0.42352942  0.42352942]
#    [ 0.38431373  0.38431373  0.38431373]
#    [ 0.38431373  0.38431373  0.38431373]]
#
#   [[ 0.28627452  0.28627452  0.28627452]
#    [ 0.28627452  0.28627452  0.28627452]
#    [ 0.32549021  0.32549021  0.32549021]
#    ...,
#    [ 0.34901962  0.34901962  0.34901962]
#    [ 0.32156864  0.32156864  0.32156864]
#    [ 0.32156864  0.32156864  0.32156864]]
#
#   [[ 0.25098041  0.25098041  0.25098041]
#    [ 0.25098041  0.25098041  0.25098041]
#    [ 0.29411766  0.29411766  0.29411766]
#    ...,
#    [ 0.32156864  0.32156864  0.32156864]
#    [ 0.28235295  0.28235295  0.28235295]
#    [ 0.28235295  0.28235295  0.28235295]]
#
#   ...,
#   [[ 0.78431374  0.78431374  0.78431374]
#    [ 0.78431374  0.78431374  0.78431374]
#    [ 0.80784315  0.80784315  0.80784315]
#    ...,
#    [ 0.86274511  0.86274511  0.86274511]
#    [ 0.84705883  0.84705883  0.84705883]
#    [ 0.84705883  0.84705883  0.84705883]]
#
#   [[ 0.76078433  0.76078433  0.76078433]
#    [ 0.76078433  0.76078433  0.76078433]
#    [ 0.78431374  0.78431374  0.78431374]
#    ...,
#    [ 0.8392157   0.8392157   0.8392157 ]
#    [ 0.82352942  0.82352942  0.82352942]
#    [ 0.82352942  0.82352942  0.82352942]]
#
#   [[ 0.75294119  0.75294119  0.75294119]
#    [ 0.75294119  0.75294119  0.75294119]
#    [ 0.76862746  0.76862746  0.76862746]
#    ...,
#    [ 0.80000001  0.80000001  0.80000001]
#    [ 0.79215688  0.79215688  0.79215688]
#    [ 0.79215688  0.79215688  0.79215688]]]
#
#
#  [[[ 0.35294119  0.35294119  0.35294119]
#    [ 0.35294119  0.35294119  0.35294119]
#    [ 0.38039216  0.38039216  0.38039216]
#    ...,
#    [ 0.38431373  0.38431373  0.38431373]
#    [ 0.36078432  0.36078432  0.36078432]
#    [ 0.36078432  0.36078432  0.36078432]]
#
#   [[ 0.28235295  0.28235295  0.28235295]
#    [ 0.28235295  0.28235295  0.28235295]
#    [ 0.3137255   0.3137255   0.3137255 ]
#    ...,
#    [ 0.3137255   0.3137255   0.3137255 ]
#    [ 0.28235295  0.28235295  0.28235295]
#    [ 0.28235295  0.28235295  0.28235295]]
#
#   [[ 0.23921569  0.23921569  0.23921569]
#    [ 0.23921569  0.23921569  0.23921569]
#    [ 0.27843139  0.27843139  0.27843139]
#    ...,
#    [ 0.27843139  0.27843139  0.27843139]
#    [ 0.23921569  0.23921569  0.23921569]
#    [ 0.23921569  0.23921569  0.23921569]]
#
#   ...,
#   [[ 0.84313726  0.84313726  0.84313726]
#    [ 0.84313726  0.84313726  0.84313726]
#    [ 0.85882354  0.85882354  0.85882354]
#    ...,
#    [ 0.93725491  0.93725491  0.93725491]
#    [ 0.94117647  0.94117647  0.94117647]
#    [ 0.94117647  0.94117647  0.94117647]]
#
#   [[ 0.80392158  0.80392158  0.80392158]
#    [ 0.80392158  0.80392158  0.80392158]
#    [ 0.82352942  0.82352942  0.82352942]
#    ...,
#    [ 0.90588236  0.90588236  0.90588236]
#    [ 0.91764706  0.91764706  0.91764706]
#    [ 0.91764706  0.91764706  0.91764706]]
#
#   [[ 0.78039217  0.78039217  0.78039217]
#    [ 0.78039217  0.78039217  0.78039217]
#    [ 0.80000001  0.80000001  0.80000001]
#    ...,
#    [ 0.89019608  0.89019608  0.89019608]
#    [ 0.90196079  0.90196079  0.90196079]
#    [ 0.90196079  0.90196079  0.90196079]]]
#
#
#  [[[ 0.48627451  0.48627451  0.48627451]
#    [ 0.48627451  0.48627451  0.48627451]
#    [ 0.50980395  0.50980395  0.50980395]
#    ...,
#    [ 0.40784314  0.40784314  0.40784314]
#    [ 0.3764706   0.3764706   0.3764706 ]
#    [ 0.3764706   0.3764706   0.3764706 ]]
#
#   [[ 0.41960785  0.41960785  0.41960785]
#    [ 0.41960785  0.41960785  0.41960785]
#    [ 0.4509804   0.4509804   0.4509804 ]
#    ...,
#    [ 0.34509805  0.34509805  0.34509805]
#    [ 0.30980393  0.30980393  0.30980393]
#    [ 0.30980393  0.30980393  0.30980393]]
#
#   [[ 0.39607844  0.39607844  0.39607844]
#    [ 0.39607844  0.39607844  0.39607844]
#    [ 0.43529412  0.43529412  0.43529412]
#    ...,
#    [ 0.3137255   0.3137255   0.3137255 ]
#    [ 0.27843139  0.27843139  0.27843139]
#    [ 0.27843139  0.27843139  0.27843139]]
#
#   ...,
#   [[ 0.93725491  0.93725491  0.93725491]
#    [ 0.93725491  0.93725491  0.93725491]
#    [ 0.93725491  0.93725491  0.93725491]
#    ...,
#    [ 0.78823531  0.78823531  0.78823531]
#    [ 0.7764706   0.7764706   0.7764706 ]
#    [ 0.7764706   0.7764706   0.7764706 ]]
#
#   [[ 0.92941177  0.92941177  0.92941177]
#    [ 0.92941177  0.92941177  0.92941177]
#    [ 0.91764706  0.91764706  0.91764706]
#    ...,
#    [ 0.78823531  0.78823531  0.78823531]
#    [ 0.77254903  0.77254903  0.77254903]
#    [ 0.77254903  0.77254903  0.77254903]]
#
#   [[ 0.96862745  0.96862745  0.96862745]
#    [ 0.96862745  0.96862745  0.96862745]
#    [ 0.94117647  0.94117647  0.94117647]
#    ...,
#    [ 0.80392158  0.80392158  0.80392158]
#    [ 0.78431374  0.78431374  0.78431374]
#    [ 0.78431374  0.78431374  0.78431374]]]]

# %%
def cnn_model_fn(features, labels, mode):
  """Model function for CNN."""
  # Input Layer
  input_layer = tf.reshape(features, [-1, 96, 96, 3])

  # Convolutional Layer #1
  conv1 = tf.layers.conv2d(
      inputs=input_layer,
      filters=32,
      kernel_size=[5, 5],
      padding="same",
      activation=tf.nn.relu)

  # Pooling Layer #1
  pool1 = tf.layers.max_pooling2d(inputs=conv1, pool_size=[2, 2], strides=2) 

  # Convolutional Layer #2 and Pooling Layer #2
  conv2 = tf.layers.conv2d(
      inputs=pool1,
      filters=64,
      kernel_size=[5, 5],
      padding="same",
      activation=tf.nn.relu)
  pool2 = tf.layers.max_pooling2d(inputs=conv2, pool_size=[2, 2], strides=2)

  # Dense Layer
  pool2_flat = tf.reshape(pool2, [-1, 36864])
  dense = tf.layers.dense(inputs=pool2_flat, units=1024, activation=tf.nn.relu)
  dropout = tf.layers.dropout(
      inputs=dense, rate=0.4, training=mode == tf.estimator.ModeKeys.TRAIN)

  # Logits Layer
  logits = tf.layers.dense(inputs=dropout, units=3)

  predictions = {
      # Generate predictions (for PREDICT and EVAL mode)
      "classes": tf.argmax(input=logits, axis=1),
      # Add `softmax_tensor` to the graph. It is used for PREDICT and by the
      # `logging_hook`.
      "probabilities": tf.nn.softmax(logits, name="softmax_tensor")
  }
    
  if mode == tf.estimator.ModeKeys.PREDICT:
    return tf.estimator.EstimatorSpec(mode=mode, predictions=predictions)

  # Calculate Loss (for both TRAIN and EVAL modes)
  loss = tf.losses.sparse_softmax_cross_entropy(labels=labels, logits=logits)

  # Configure the Training Op (for TRAIN mode)
  if mode == tf.estimator.ModeKeys.TRAIN:
    optimizer = tf.train.GradientDescentOptimizer(learning_rate=0.1)
    train_op = optimizer.minimize(
        loss=loss,
        global_step=tf.train.get_global_step())
    return tf.estimator.EstimatorSpec(mode=mode, loss=loss, train_op=train_op)

  # Add evaluation metrics (for EVAL mode)
  eval_metric_ops = {
      "accuracy": tf.metrics.accuracy(
          labels=labels, predictions=predictions["classes"])}
  return tf.estimator.EstimatorSpec(
      mode=mode, loss=loss, eval_metric_ops=eval_metric_ops)

# %%
def construct_feature_columns():
  # There are 9216 pixels in each image.
  return set([tf.feature_column.numeric_column('pixels', shape=9216)])

# %%
def create_predict_input_fn(features, labels, batch_size):#, num_epochs=None, shuffle=True):
#     print("predict input fn")
#     print(type(features))
#     print(type(labels))
#     print(type(batch_size))
    predict_input_fn = tf.estimator.inputs.numpy_input_fn(
        x=features,
        y=labels,
        num_epochs=1,
        shuffle=False)
    return predict_input_fn

def create_training_input_fn(features, labels, batch_size):#, num_epochs=None, shuffle=True):
#     print("training input fn")
#     print(type(features))
#     print(type(labels))
#     print(type(batch_size))
    train_input_fn = tf.estimator.inputs.numpy_input_fn(
        x=features,
        y=labels,
        batch_size=batch_size,
        num_epochs=None,
        shuffle=True)
    return train_input_fn

# %%
def train_hub_classification_model(
    learning_rate,
    steps,
    batch_size,
    hidden_units,
    training_examples,
    training_targets,
    validation_examples,
    validation_targets):

    periods = 10
    steps_per_period = steps / periods 
#     tensors_to_log = {"probabilities": "softmax_tensor"}
# #     logging_hook = tf.train.LoggingTensorHook(
# #         tensors=tensors_to_log, every_n_iter=10)
    
    predict_training_input_fn = create_predict_input_fn(training_examples, training_targets, batch_size)
    predict_validation_input_fn = create_predict_input_fn(validation_examples, validation_targets, batch_size)
  
    training_input_fn = create_training_input_fn(training_examples, training_targets, batch_size)
    predict_training_input_fn = create_predict_input_fn(training_examples, training_targets, batch_size)
    
    predict_validation_input_fn = create_predict_input_fn(validation_examples, validation_targets, batch_size)
    training_input_fn = create_training_input_fn(training_examples, training_targets, batch_size)
  
    feature_columns = [tf.feature_column.numeric_column('pixels', shape=9216)]

    my_optimizer = tf.train.AdagradOptimizer(learning_rate=learning_rate)
    my_optimizer = tf.contrib.estimator.clip_gradients_by_norm(my_optimizer, 5.0)
###############################################################
    classifier = tf.estimator.Estimator(
    model_fn=cnn_model_fn,
    model_dir="./mode_CNN_5"
    )
##############################################################################
    # Train the model, but do so inside a loop so that we can periodically assess
    # loss metrics.
    print("Training model...")
    print("LogLoss error (on validation data):")
    training_errors = []
    validation_errors = []
    for period in range (0, periods):
        classifier.train(
            input_fn=training_input_fn,
            steps=steps_per_period,
        )
        training_predictions = list(classifier.predict(input_fn=predict_training_input_fn))
        training_probabilities = np.array([item['probabilities'] for item in training_predictions])
        training_pred_class_id = np.array([item['classes'] for item in training_predictions])
        training_pred_one_hot = tf.keras.utils.to_categorical(training_pred_class_id,3) #change class number

        validation_predictions = list(classifier.predict(input_fn=predict_validation_input_fn))
        validation_probabilities = np.array([item['probabilities'] for item in validation_predictions])    
        validation_pred_class_id = np.array([item['classes'] for item in validation_predictions])
        validation_pred_one_hot = tf.keras.utils.to_categorical(validation_pred_class_id,3) #change class number

        # Compute training and validation errors.
        training_log_loss = metrics.log_loss(training_targets, training_pred_one_hot)
        validation_log_loss = metrics.log_loss(validation_targets, validation_pred_one_hot)
        # Occasionally print the current loss.
        print("  period %02d : %0.2f" % (period, validation_log_loss))
        # Add the loss metrics from this period to our list.
        training_errors.append(training_log_loss)
        validation_errors.append(validation_log_loss)
        
    print("Model training finished.")
    # Remove event files to save disk space.
    _ = map(os.remove, glob.glob(os.path.join(classifier.model_dir, 'events.out.tfevents*')))

    # Calculate final predictions (not probabilities, as above).
    final_predictions = classifier.predict(input_fn=predict_validation_input_fn)
    final_predictions = np.array([item['classes'] for item in final_predictions])


    accuracy = metrics.accuracy_score(validation_targets, final_predictions)
    print("Final accuracy (on validation data): %0.2f" % accuracy)

    # Output a graph of loss metrics over periods.
    plt.ylabel("LogLoss")
    plt.xlabel("Periods")
    plt.title("LogLoss vs. Periods")
    plt.plot(training_errors, label="training")
    plt.plot(validation_errors, label="validation")
    plt.legend()
    plt.show()

    # Output a plot of the confusion matrix.
    cm = metrics.confusion_matrix(validation_targets, final_predictions)
    # Normalize the confusion matrix by row (i.e by the number of samples
    # in each class).
    cm_normalized = cm.astype("float") / cm.sum(axis=1)[:, np.newaxis]
    ax = sns.heatmap(cm_normalized, cmap="bone_r")
    ax.set_aspect(1)
    plt.title("Confusion matrix")
    plt.ylabel("True label")
    plt.xlabel("Predicted label")
    plt.show()

    return classifier

# %%
#len(set(training_targets))
#validation_targets
print(validation_examples.shape)
print(len(validation_examples))
# Out:
# (1165, 96, 96, 3)
# 1165

# %%
print(len(set(validation_targets)))
print(len(set(training_targets)))
# Out:
# 3
# 3

# %%
classifier = train_hub_classification_model(
    learning_rate=0.01,
    steps=1000,
    batch_size=100,
    hidden_units=[200, 200],
    training_examples=training_examples,
    training_targets=training_targets,
    validation_examples=validation_examples,
    validation_targets=validation_targets)
# Out:
# Training model...
# LogLoss error (on validation data):

# %%
# !sudo shutdown -h now

# %%
classifier = tf.estimator.Estimator(
    model_fn=cnn_model_fn,
    model_dir="./mode_CNN_2",
    )

# %%
def my_test_input_fn(features, batch_size=1, num_epochs=None):
    raw_features = features
    ds = Dataset.from_tensor_slices((raw_features))
    ds = ds.batch(batch_size).repeat(num_epochs)
    features = ds.make_one_shot_iterator().get_next()
    return features

predict_test_input_fn = lambda: my_test_input_fn(
    test_images,
    num_epochs=1,)

# %%
test_images = []
fnames = []
all_files = [y for y in os.listdir(test_pict_path) if '.jpg' in y]
print(type(all_files))
i = 0
test_images = []
fnames = []
for file in all_files[:50000]:
    test_images.append(cv2.imread(test_pict_path + file))
    fnames.append(file[:-4] + '.wav')
test_images = np.array(test_images, dtype="float32")
test_images /= 255
test_predictions = classifier.predict(input_fn=predict_test_input_fn)
test_predictions = np.array([item['classes'] for item in test_predictions])

my_submission = pd.DataFrame({'fname': fnames, 'label': test_predictions})
# you could use any filename. We choose submission here
my_submission.to_csv('sub_voice_' + 'x' + '.csv', index=False)

# %%
# kernel keeps dying when running all test files, so I split it into thirds and concat the datasets afterward.
test_images = []
fnames = []
all_files = [y for y in os.listdir(test_pict_path) if '.jpg' in y]
print(type(all_files))
i = 0
test_images = []
fnames = []
for file in all_files[50000:100000]:
    test_images.append(cv2.imread(test_pict_path + file))
    fnames.append(file[:-4] + '.wav')
test_images = np.array(test_images, dtype="float32")
test_images /= 255
test_predictions = classifier.predict(input_fn=predict_test_input_fn)
test_predictions = np.array([item['classes'] for item in test_predictions])

my_submission = pd.DataFrame({'fname': fnames, 'label': test_predictions})
# you could use any filename. We choose submission here
my_submission.to_csv('sub_voice_' + 'y' + '.csv', index=False)

# %%
test_images = []
fnames = []
all_files = [y for y in os.listdir(test_pict_path) if '.jpg' in y]
print(type(all_files))
i = 0
test_images = []
fnames = []
for file in all_files[100000:]:
    test_images.append(cv2.imread(test_pict_path + file))
    fnames.append(file[:-4] + '.wav')
test_images = np.array(test_images, dtype="float32")
test_images /= 255
test_predictions = classifier.predict(input_fn=predict_test_input_fn)
test_predictions = np.array([item['classes'] for item in test_predictions])

my_submission = pd.DataFrame({'fname': fnames, 'label': test_predictions})
# you could use any filename. We choose submission here
my_submission.to_csv('sub_voice_' + 'z' + '.csv', index=False)

# %%
d0 = pd.read_csv("./sub_voice_" + 'x' + ".csv",sep=",")
d1 = pd.read_csv("./sub_voice_" + 'y' + ".csv",sep=",")
d2 = pd.read_csv("./sub_voice_" + 'z' + ".csv",sep=",")

df = [d0,d1,d2]
dx = pd.concat(df)

dx = dx.replace({"label": reverse_dict})

dx.to_csv('sub_CNN2.csv', index=False)
dx
